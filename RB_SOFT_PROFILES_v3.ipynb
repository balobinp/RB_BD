# %% [markdown]
# # С помощью этой методики можно найти свободные IMSI диапазоны, а также создать файл с ключами для отправки кастомеру

# %%
# Загрузить данные из файлов
# Задать имена аккаунтов и файлов
#----------------------------------

import pandas as pd
from pandas import DataFrame
from os.path import join, normpath
import datetime as dt

downloads = r'c:\Users\balob\Documents\GITLAB\RB_BD\DATA\SoftProfiles\Data'
result_file = 'result_file.csv'
files = ['rb_42501_25_06_20181.txt', 'rb_42501_2_09_20181.txt', 'rb_26006_25_06_20181.txt', 'rb_26006_2_09_20181.txt']

reseller_name = 'Tottolli-Tech-Mobil'
s1_account_name = 'Tottolli S1 Soft'
s2_account_name = 'Tottolli S2 Soft'

customer_name = 'Tottolli' # to use as a file name

current_date = dt.datetime.now().strftime('%y%m%d')
file_s1_name = f'S1_{customer_name}_{current_date}.txt'
file_s2_name = f'S2_{customer_name}_{current_date}.txt'

df_imsi = DataFrame(columns = ['IMSI', 'KI', 'OPC'])

for file in files:
    df_imsi = df_imsi.append(pd.read_table(join(downloads, file), sep=' ',header=0, engine='python'))

df_imsi.IMSI = df_imsi.IMSI.astype('int64')
df_imsi.sort_values(by = 'IMSI', inplace = True)

df_imsi.head()
# Out:
#               IMSI                                KI  \
# 0  260060140890000  1AEA5D122A1F2476EBD9350F10C0EFDD
# 1  260060140890001  09B595FF54EEFE9E547237B4D7499202
# 2  260060140890002  744A3D38AFBCBB0292FF9807D21E8B4D
# 3  260060140890003  2244EDED489D62B569EC8179FC73489F
# 4  260060140890004  FCB72503EA93EEB2A36CFBC23256697D
#
#                                 OPC
# 0  5EE04A60E740AF9890C397A899109B25
# 1  9274F199697E5775100367CAE65B24D0
# 2  8D7B5100C7BF361382490BFA632F8A55
# 3  2D63E23033BB91337C8DD03362984B44
# 4  7697EA5B130950C519EDA1487C50CE2F

# %%
# Предварительная проверка диапазонов (опционально)
#----------------------------------

list_agg = [('IMSI_MIN','min'),('IMSI_MAX','max'),('NUM','count')]

df = df_imsi.groupby(df_imsi.IMSI.astype('str').str.slice(0,12))['IMSI'].agg(list_agg).reset_index()
df.IMSI = df.IMSI.astype('int64')
df.rename(columns = {'IMSI':'IMSI_RANGE'}, inplace = True)

df['imsi_shifted'] = df['IMSI_RANGE'].shift(-1)
df.fillna(0,inplace=True)
df['imsi_shifted'] = df['imsi_shifted'].astype('int64')

def check_imsi(x):
    x['imsi_num'] = x['IMSI_MAX'] - x['IMSI_MIN'] + 1
    x['check_range'] = x['imsi_shifted'] - x['IMSI_RANGE']
    if x['NUM'] == (x['IMSI_MAX'] - x['IMSI_MIN'] + 1):
        x['imsi_num_check'] = 'OK'
    else:
        x['imsi_num_check'] = 'NOK'
    return x

df = df.apply(check_imsi, axis=1)

# %%
df.head(3)
# Out:
#      IMSI_RANGE         IMSI_MIN         IMSI_MAX   NUM  imsi_shifted  \
# 0  260060140890  260060140890000  260060140890999  1000  260060140891
# 1  260060140891  260060140891000  260060140891999  1000  260060140892
# 2  260060140892  260060140892000  260060140892999  1000  260060140893
#
#    imsi_num  check_range imsi_num_check
# 0      1000            1             OK
# 1      1000            1             OK
# 2      1000            1             OK

# %%
# df.to_csv(join(downloads,'soft_ranges.csv'), index=False)

# %%
# Из базы данных OCS выгружаем IMSI
#----------------------------------

import pandas as pd
import pyodbc 
#Connect to OCSDBREP1 (BSS)
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER=172.18.11.82;DATABASE=10028;UID=BSS;PWD=iKQVm40AZAmyRaw72LeY')

sql_srt=\
'''
SELECT DISTINCT
r.RESELLER_NAME
,a.ACCOUNT_NAME
,ss.STATUS AS SUB_STATUS
,si.IMSI
FROM RESELLERS r
INNER JOIN ACCOUNTS a
ON r.RESELLER_ID = a.RESELLER_ID
INNER JOIN SUBSCRIBERS sr
ON sr.ACCOUNT_ID = a.ACCOUNT_ID
INNER JOIN SUBSCRIBER_STATUS ss
ON ss.SUBSCRIBER_ID = sr.SUBSCRIBER_ID
INNER JOIN SUBSCRIBER_IMSIS si
ON ss.SUBSCRIBER_ID = si.SUBSCRIBER_ID
WHERE
r.deleted is NULL
AND ss.END_DATE IS NULL
AND ss.status = 'Active'
AND
(si.IMSI BETWEEN '260060140890000' AND '260060140899999'
OR si.IMSI BETWEEN  '260060149991100' AND '260060149999999'
OR si.IMSI BETWEEN  '425019613998060' AND '425019613999999'
OR si.IMSI BETWEEN  '425019629920000' AND '425019629939999')
'''

df_ocs_imsi = pd.read_sql_query(sql_srt, cnxn, coerce_float=False)
df_ocs_imsi['IMSI'] = df_ocs_imsi['IMSI'].astype('int64')
cnxn.close()
df_ocs_imsi.head()
# Out:
#              RESELLER_NAME              ACCOUNT_NAME SUB_STATUS  \
# 0                Acloud RT               Acloud Test     Active
# 1                Acloud RT               Acloud Test     Active
# 2                Acloud RT               Acloud Test     Active
# 3  Dialoq - Genesisclub RT  Genesisclub P4 Soft test     Active
# 4  Dialoq - Genesisclub RT  Genesisclub P4 Soft test     Active
#
#               IMSI
# 0  260060149991109
# 1  425019613998068
# 2  425019613998069
# 3  260060149991110
# 4  260060149991115

# %%
# Объединяем IMSI с ключами с данными OCS
#----------------------------------

df_ocs_imsi_ki = pd.merge(df_imsi, df_ocs_imsi, how='left', on='IMSI')
list_agg = [('IMSI_MIN','min'),('IMSI_MAX','max'),('NUM','count')]
list_col = ['RESELLER_NAME', 'ACCOUNT_NAME', 'SUB_STATUS', df_ocs_imsi_ki.IMSI.astype('str').str.slice(0,12)]
df_ocs_imsi_ki_group = df_ocs_imsi_ki.groupby(list_col)['IMSI'].agg(list_agg).reset_index().sort_values(by='IMSI')

df_ocs_imsi_ki_group.head()
# Out:
#    RESELLER_NAME          ACCOUNT_NAME SUB_STATUS          IMSI  \
# 14   MCN Telecom  MCN Telecom Soft SIM     Active  260060140890
# 15   MCN Telecom  MCN Telecom Soft SIM     Active  260060140891
# 16   MCN Telecom  MCN Telecom Soft SIM     Active  260060140892
# 17   MCN Telecom  MCN Telecom Soft SIM     Active  260060140893
# 18   MCN Telecom  MCN Telecom Soft SIM     Active  260060140894
#
#            IMSI_MIN         IMSI_MAX   NUM
# 14  260060140890000  260060140890999  1000
# 15  260060140891000  260060140891999  1000
# 16  260060140892000  260060140892999  1000
# 17  260060140893000  260060140893999   995
# 18  260060140894000  260060140894999  1000

# %%
# For test accounts to use the following ranges:
# S1: 425019613998*
# S2: 260060149991*
# Выбрать свободные из "Roamability Invertory"

s1_test_soft_range = '425019613998'
s2_test_soft_range = '260060149991'

print('S1 test IMSIs in OCS by Reseller:')
display(df_ocs_imsi_ki_group[df_ocs_imsi_ki_group['IMSI'] == s1_test_soft_range].sort_values('IMSI_MIN'))

print('S2 test IMSIs in OCS by Reseller:')
display(df_ocs_imsi_ki_group[df_ocs_imsi_ki_group['IMSI'] == s2_test_soft_range].sort_values('IMSI_MIN'))
# Out:
# S1 test IMSIs in OCS by Reseller:
#                               RESELLER_NAME                     ACCOUNT_NAME  \
# 5   Flexiroam Limited -- TESTING at 2018-07      Flexiroam Test Soft simcard
# 16                              MCN Telecom             MCN Telecom Soft SIM
# 1                                 Acloud RT                      Acloud Test
# 64                                    XOtel               XOtel Test account
# 56                      Tottolli-Tech-Mobil                   Test Sim cards
# 3                   Dialoq - Genesisclub RT    Genesisclub Partner Soft test
# 54                             Tapmobile RT         Tapmobile Test Sim cards
# 9                               Joy telecom    Joy telecom Partner Soft test
# 61                             Watchdata SG     Watchdata  Partner Soft test
# 34                    Roamability Invertory  Partner Soft simcards inventory
# 50                                 Simlocal                   Test SIM cards
# 52                                   Taisys                   Test Sim cards
#
#    SUB_STATUS          IMSI         IMSI_MIN         IMSI_MAX  NUM
# 5      Active  425019613998  425019613998060  425019613998064    5
# 16     Active  425019613998  425019613998065  425019613998067    3
# 1      Active  425019613998  425019613998068  425019613998069    2
# 64     Active  425019613998  425019613998070  425019613998070    1
# 56     Active  425019613998  425019613998071  425019613998081    4
# 3      Active  425019613998  425019613998072  425019613998087   11
# 54     Active  425019613998  425019613998078  425019613998078    1
# 9      Active  425019613998  425019613998088  425019613998092    4
# 61     Active  425019613998  425019613998090  425019613998090    1
# 34     Active  425019613998  425019613998093  425019613998995  903
# 50     Active  425019613998  425019613998996  425019613998996    1
# 52     Active  425019613998  425019613998997  425019613998999    3
# S2 test IMSIs in OCS by Reseller:
#                               RESELLER_NAME                 ACCOUNT_NAME  \
# 4   Flexiroam Limited -- TESTING at 2018-07  Flexiroam Test Soft simcard
# 15                              MCN Telecom         MCN Telecom Soft SIM
# 0                                 Acloud RT                  Acloud Test
# 2                   Dialoq - Genesisclub RT     Genesisclub P4 Soft test
# 53                             Tapmobile RT     Tapmobile Test Sim cards
# 62                             Watchdata SG       Watchdata P4 Soft test
# 25                    Roamability Invertory   P4 Soft simcards inventory
# 49                                 Simlocal               Test SIM cards
# 8                               Joy telecom     Joy telecom P4 Soft test
# 51                                   Taisys               Test Sim cards
#
#    SUB_STATUS          IMSI         IMSI_MIN         IMSI_MAX  NUM
# 4      Active  260060149991  260060149991100  260060149991104    5
# 15     Active  260060149991  260060149991105  260060149991107    3
# 0      Active  260060149991  260060149991108  260060149991109    2
# 2      Active  260060149991  260060149991110  260060149991122   12
# 53     Active  260060149991  260060149991116  260060149991116    1
# 62     Active  260060149991  260060149991123  260060149991123    1
# 25     Active  260060149991  260060149991124  260060149991993  870
# 49     Active  260060149991  260060149991994  260060149991994    1
# 8      Active  260060149991  260060149991995  260060149991996    2
# 51     Active  260060149991  260060149991997  260060149991999    3

# %%
# For commersial usage

# S1 profiles
print('S1 prod IMSIs in OCS by Reseller:')
display(df_ocs_imsi_ki_group[df_ocs_imsi_ki_group.IMSI.str.startswith('42501', na=False)])

# S2 profiles
print('S2 prod IMSIs in OCS by Reseller:')
display(df_ocs_imsi_ki_group[df_ocs_imsi_ki_group.IMSI.str.startswith('26006', na=False)])
# Out:
# S1 prod IMSIs in OCS by Reseller:
#                               RESELLER_NAME  \
# 12                         Justworks Mobile
# 51                             Tapmobile RT
# 41                    Roamability Invertory
# 67                                    XOtel
# 20                              MCN Telecom
# 31                                RedTea RT
# 53                      Tottolli-Tech-Mobil
# 9                               Joy telecom
# 5   Flexiroam Limited -- TESTING at 2018-07
# 3                   Dialoq - Genesisclub RT
# 64                             Watchdata SG
# 1                                 Acloud RT
# 47                                 Simlocal
# 49                                   Taisys
# 7              Iturbag -- TESING at 2018-07
# 42                    Roamability Invertory
# 21                              MCN Telecom
# 22                              MCN Telecom
# 23                              MCN Telecom
# 24                              MCN Telecom
# 25                              MCN Telecom
# 26                                RedTea RT
# 27                                RedTea RT
# 10                              Joy telecom
# 11                              Joy telecom
# 28                                RedTea RT
# 29                                RedTea RT
# 30                                RedTea RT
# 54                      Tottolli-Tech-Mobil
# 55                      Tottolli-Tech-Mobil
# 56                      Tottolli-Tech-Mobil
# 43                    Roamability Invertory
# 44                    Roamability Invertory
# 45                    Roamability Invertory
# 57                      Tottolli-Tech-Mobil
# 58                      Tottolli-Tech-Mobil
#
#                                  ACCOUNT_NAME SUB_STATUS          IMSI  \
# 12                 Justworks S1 test soft SIM     Active  425019613998
# 51                   Tapmobile Test Sim cards     Active  425019613998
# 41            Partner Soft simcards inventory     Active  425019613998
# 67                         XOtel Test account     Active  425019613998
# 20                       MCN Telecom Soft SIM     Active  425019613998
# 31          RedTea TEST Soft-simcards account     Active  425019613998
# 53                             Test Sim cards     Active  425019613998
# 9               Joy telecom Partner Soft test     Active  425019613998
# 5                 Flexiroam Test Soft simcard     Active  425019613998
# 3               Genesisclub Partner Soft test     Active  425019613998
# 64               Watchdata  Partner Soft test     Active  425019613998
# 1                                 Acloud Test     Active  425019613998
# 47                             Test SIM cards     Active  425019613998
# 49                             Test Sim cards     Active  425019613998
# 7                        Iturbag test account     Active  425019613999
# 42            Partner Soft simcards inventory     Active  425019613999
# 21                       MCN Telecom Soft SIM     Active  425019629920
# 22                       MCN Telecom Soft SIM     Active  425019629921
# 23                       MCN Telecom Soft SIM     Active  425019629922
# 24                       MCN Telecom Soft SIM     Active  425019629923
# 25                       MCN Telecom Soft SIM     Active  425019629924
# 26  RedTea S1 Soft-simcards india IOT project     Active  425019629925
# 27  RedTea S1 Soft-simcards india IOT project     Active  425019629926
# 10                 Joy telecom S1 Soft Turkey     Active  425019629927
# 11                 Joy telecom S1 Soft Turkey     Active  425019629928
# 28  RedTea S1 Soft-simcards india IOT project     Active  425019629929
# 29  RedTea S1 Soft-simcards india IOT project     Active  425019629930
# 30  RedTea S1 Soft-simcards india IOT project     Active  425019629931
# 54                           Tottolli S1 Soft     Active  425019629932
# 55                           Tottolli S1 Soft     Active  425019629933
# 56                           Tottolli S1 Soft     Active  425019629934
# 43            Partner Soft simcards inventory     Active  425019629935
# 44            Partner Soft simcards inventory     Active  425019629936
# 45            Partner Soft simcards inventory     Active  425019629937
# 57                           Tottolli S1 Soft     Active  425019629938
# 58                           Tottolli S1 Soft     Active  425019629939
#
#            IMSI_MIN         IMSI_MAX   NUM
# 12  425019613998995  425019613998995     1
# 51  425019613998078  425019613998078     1
# 41  425019613998113  425019613998994   882
# 67  425019613998070  425019613998070     1
# 20  425019613998065  425019613998067     3
# 31  425019613998093  425019613998112    20
# 53  425019613998071  425019613998081     4
# 9   425019613998088  425019613998092     4
# 5   425019613998060  425019613998064     5
# 3   425019613998072  425019613998087    12
# 64  425019613998090  425019613998090     1
# 1   425019613998068  425019613998069     2
# 47  425019613998996  425019613998996     1
# 49  425019613998997  425019613998999     3
# 7   425019613999998  425019613999999     2
# 42  425019613999000  425019613999997   998
# 21  425019629920000  425019629920999  1000
# 22  425019629921000  425019629921999  1000
# 23  425019629922000  425019629922999  1000
# 24  425019629923000  425019629923999  1000
# 25  425019629924000  425019629924999  1000
# 26  425019629925000  425019629925999  1000
# 27  425019629926000  425019629926999  1000
# 10  425019629927000  425019629927999  1000
# 11  425019629928000  425019629928999  1000
# 28  425019629929000  425019629929999  1000
# 29  425019629930000  425019629930999  1000
# 30  425019629931000  425019629931999  1000
# 54  425019629932000  425019629932999  1000
# 55  425019629933000  425019629933999  1000
# 56  425019629934000  425019629934999  1000
# 43  425019629935000  425019629935999  1000
# 44  425019629936000  425019629936999  1000
# 45  425019629937000  425019629937999  1000
# 57  425019629938000  425019629938999  1000
# 58  425019629939000  425019629939999  1000
# S2 prod IMSIs in OCS by Reseller:
#                               RESELLER_NAME                 ACCOUNT_NAME  \
# 14                              MCN Telecom         MCN Telecom Soft SIM
# 15                              MCN Telecom         MCN Telecom Soft SIM
# 16                              MCN Telecom         MCN Telecom Soft SIM
# 17                              MCN Telecom         MCN Telecom Soft SIM
# 18                              MCN Telecom         MCN Telecom Soft SIM
# 59                      Tottolli-Tech-Mobil             Tottolli S2 Soft
# 60                      Tottolli-Tech-Mobil             Tottolli S2 Soft
# 61                      Tottolli-Tech-Mobil             Tottolli S2 Soft
# 62                      Tottolli-Tech-Mobil             Tottolli S2 Soft
# 63                      Tottolli-Tech-Mobil             Tottolli S2 Soft
# 0                                 Acloud RT                  Acloud Test
# 13                         Justworks Mobile   Justworks S2 test soft SIM
# 50                             Tapmobile RT     Tapmobile Test Sim cards
# 48                                   Taisys               Test Sim cards
# 19                              MCN Telecom         MCN Telecom Soft SIM
# 8                               Joy telecom     Joy telecom P4 Soft test
# 4   Flexiroam Limited -- TESTING at 2018-07  Flexiroam Test Soft simcard
# 2                   Dialoq - Genesisclub RT     Genesisclub P4 Soft test
# 65                             Watchdata SG       Watchdata P4 Soft test
# 46                                 Simlocal               Test SIM cards
# 32                    Roamability Invertory   P4 Soft simcards inventory
# 33                    Roamability Invertory   P4 Soft simcards inventory
# 34                    Roamability Invertory   P4 Soft simcards inventory
# 35                    Roamability Invertory   P4 Soft simcards inventory
# 36                    Roamability Invertory   P4 Soft simcards inventory
# 37                    Roamability Invertory   P4 Soft simcards inventory
# 38                    Roamability Invertory   P4 Soft simcards inventory
# 39                    Roamability Invertory   P4 Soft simcards inventory
# 52                      Tottolli-Tech-Mobil               Test Sim cards
# 6              Iturbag -- TESING at 2018-07         Iturbag test account
# 40                    Roamability Invertory   P4 Soft simcards inventory
# 66                                    XOtel           XOtel Test account
#
#    SUB_STATUS          IMSI         IMSI_MIN         IMSI_MAX   NUM
# 14     Active  260060140890  260060140890000  260060140890999  1000
# 15     Active  260060140891  260060140891000  260060140891999  1000
# 16     Active  260060140892  260060140892000  260060140892999  1000
# 17     Active  260060140893  260060140893000  260060140893999   995
# 18     Active  260060140894  260060140894000  260060140894999  1000
# 59     Active  260060140895  260060140895000  260060140895999  1000
# 60     Active  260060140896  260060140896000  260060140896999  1000
# 61     Active  260060140897  260060140897000  260060140897999  1000
# 62     Active  260060140898  260060140898000  260060140898999  1000
# 63     Active  260060140899  260060140899000  260060140899999  1000
# 0      Active  260060149991  260060149991108  260060149991109     2
# 13     Active  260060149991  260060149991993  260060149991993     1
# 50     Active  260060149991  260060149991116  260060149991116     1
# 48     Active  260060149991  260060149991997  260060149991999     3
# 19     Active  260060149991  260060149991105  260060149991107     3
# 8      Active  260060149991  260060149991995  260060149991996     2
# 4      Active  260060149991  260060149991100  260060149991104     5
# 2      Active  260060149991  260060149991110  260060149991122    12
# 65     Active  260060149991  260060149991123  260060149991123     1
# 46     Active  260060149991  260060149991994  260060149991994     1
# 32     Active  260060149991  260060149991124  260060149991992   869
# 33     Active  260060149992  260060149992000  260060149992999  1000
# 34     Active  260060149993  260060149993000  260060149993999  1000
# 35     Active  260060149994  260060149994000  260060149994999  1000
# 36     Active  260060149995  260060149995000  260060149995999  1000
# 37     Active  260060149996  260060149996000  260060149996999  1000
# 38     Active  260060149997  260060149997000  260060149997999  1000
# 39     Active  260060149998  260060149998000  260060149998999  1000
# 52     Active  260060149999  260060149999993  260060149999996     4
# 6      Active  260060149999  260060149999998  260060149999999     2
# 40     Active  260060149999  260060149999000  260060149999992   993
# 66     Active  260060149999  260060149999997  260060149999997     1

# %%
# Записать выбранные IMSI for test accounts
# Проверить выбранные IMSI на принадлежность к "Roamability Invertory"

imsis = ['425019613998995','260060149991993']

df_ocs_imsi[df_ocs_imsi.IMSI.astype('str').isin(imsis)].sort_values('IMSI')
# Out:
#          RESELLER_NAME                ACCOUNT_NAME SUB_STATUS             IMSI
# 1964  Justworks Mobile  Justworks S2 test soft SIM     Active  260060149991993
# 1963  Justworks Mobile  Justworks S1 test soft SIM     Active  425019613998995

# %%
# Записать выбранные диапазоны IMSI (для коммерческих аккаунтов)
# Проверить выбранные IMSI на принадлежность к "Roamability Invertory"


s1_imsi_range_start = 425019629932000
s1_imsi_range_end = 425019629934999

s2_imsi_range_start = 260060140895000
s2_imsi_range_end = 260060140897999

s1_imsis = [str(imsi) for imsi in range(s1_imsi_range_start,s1_imsi_range_end+1,1)]
s2_imsis = [str(imsi) for imsi in range(s2_imsi_range_start,s2_imsi_range_end+1,1)]

df_ocs_imsi[df_ocs_imsi.IMSI.astype('str').isin(s1_imsis)].sort_values('IMSI')
display(df_ocs_imsi[df_ocs_imsi.IMSI.astype('str').isin(s1_imsis)].groupby(['RESELLER_NAME',
                                                                            'ACCOUNT_NAME','SUB_STATUS']).count())
display(df_ocs_imsi[df_ocs_imsi.IMSI.astype('str').isin(s2_imsis)].groupby(['RESELLER_NAME',
                                                                            'ACCOUNT_NAME','SUB_STATUS']).count())
# Out:
#                                                                   IMSI
# RESELLER_NAME         ACCOUNT_NAME                    SUB_STATUS
# Roamability Invertory Partner Soft simcards inventory Active      3000
#                                                              IMSI
# RESELLER_NAME         ACCOUNT_NAME               SUB_STATUS
# Roamability Invertory P4 Soft simcards inventory Active      3000

# %%
# Создать Soft аккаунты для Реселлера и перенести туда IMSI.

print(f'Reseller: {reseller_name}\nAccount S1: {s1_account_name}\nAccount S2: {s2_account_name}')
# Out:
# Reseller: Tottolli-Tech-Mobil
# Account S1: Tottolli S1 Soft
# Account S2: Tottolli S2 Soft

# %%
# После переноса IMSI в аккаунты проверить выбранные IMSI и диапазоны (предварительно перезагрузив данные из OCS)

# Для отдельных IMSI
df_ocs_imsi[df_ocs_imsi.IMSI.astype('str').isin(imsis)].sort_values('IMSI')

# Для диапазонов IMSI
display(df_ocs_imsi[df_ocs_imsi.IMSI.astype('str').isin(s1_imsis)].groupby(['RESELLER_NAME',
                                                                            'ACCOUNT_NAME','SUB_STATUS']).count())
display(df_ocs_imsi[df_ocs_imsi.IMSI.astype('str').isin(s2_imsis)].groupby(['RESELLER_NAME',
                                                                            'ACCOUNT_NAME','SUB_STATUS']).count())
# Out:
#                                                  IMSI
# RESELLER_NAME       ACCOUNT_NAME     SUB_STATUS
# Tottolli-Tech-Mobil Tottolli S1 Soft Active      3000
#                                                  IMSI
# RESELLER_NAME       ACCOUNT_NAME     SUB_STATUS
# Tottolli-Tech-Mobil Tottolli S2 Soft Active      3000

# %%
# Выгружаем файлы с ключами
#----------------------------------

if len(s1_account_name) != 0:
    df_ocs_imsi_ki.loc[(df_ocs_imsi_ki.RESELLER_NAME == reseller_name) & (df_ocs_imsi_ki.ACCOUNT_NAME == s1_account_name)
                       & (df_ocs_imsi_ki.IMSI.astype('str').isin(s1_imsis)),
                   ['IMSI', 'KI', 'OPC']].to_csv(join(downloads, file_s1_name), index=False)

if len(s2_account_name) != 0:
    df_ocs_imsi_ki.loc[(df_ocs_imsi_ki.RESELLER_NAME == reseller_name) & (df_ocs_imsi_ki.ACCOUNT_NAME == s2_account_name)
                       & (df_ocs_imsi_ki.IMSI.astype('str').isin(s2_imsis)),
                   ['IMSI', 'KI', 'OPC']].to_csv(join(downloads, file_s2_name), index=False)

# %% [markdown]
# ### Далее шифруем и отправляем
# ----------------------------------
# 1. Упаковать оба файла в zip архив.
# 2. Выполнить экспорт открытого ключа Кастомера (дважды кликнуть по файлу ключа).
# 3. В папке с архивом по пр.кл. на zip архив и выбрать "Зашифровать"
# 4. Зашифровать своим ключем *_FOR_KEYS
# 5. Отправить кастомеру. Свой ключ отправлять не нужно.
