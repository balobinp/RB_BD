# %% [markdown]
# # С помощью данной методики можно найти свободные IMSI диапазоны, а также создать файл с ключами для отправки кастомеру

# %%
# Загрузить данные из файлов
# Задать имена аккаунтов и файлов
#----------------------------------

import pandas as pd
from pandas import DataFrame
from os.path import join, normpath
import datetime as dt
from collections import namedtuple

### Set the variables here ###

reseller_name = 'Ultrapower'
customer_name = 'Ultrapower' # to use as a file name

account_s1 = 'Ultrapower' # Account name with S1
account_s2 = 'Ultrapower' # Account name with S2
account_s4 = '' # Account name with S4
account_s5 = 'Ultrapower' # Account name with S5
account_s6 = 'Ultrapower' # Account name with S6
account_s8 = 'Ultrapower' # Account name with S8

##############################

sponsor_object = namedtuple('SponsorRange', 'sponsor test_range prod_range account_name')

s1_sponsor = sponsor_object('S1', '425019613998', '42501', account_s1)
s2_sponsor = sponsor_object('S2', '260060149991', '26006', account_s2)
s4_sponsor = sponsor_object('S4', '454030227305', '45403', account_s4)
s5_sponsor = sponsor_object('S5', '515030191000', '51503', account_s5)
s6_sponsor = sponsor_object('S6', '260036610100', '26003', account_s6)
s8_sponsor = sponsor_object('S8', '234500026400', '23450', account_s8)

downloads = r'c:\Users\balob\Documents\GITLAB\RB_BD\DATA\SoftProfiles\Data'
result_file = 'result_file.csv'
files = ['rb_42501_25_06_20181.txt',
         'rb_42501_2_09_20181.txt',
         'rb_26006_25_06_20181.txt',
         'rb_26006_2_09_20181.txt',
         'rb_26006_30_04_2019.txt',
         'rb_42501_30_04_2019.txt',
         'rb_45403_09_07_2019.txt',
         '454030227306000_454030227308999.out',
         '454030227310000_454030227310999.out',
         '515030191000000_515030191099999.out',
         'rb_soft_191103_s1.txt',
         'rb_soft_191103_s2.txt',
         'rb_soft_191103_s4.txt',
         'rb_soft_191107_s6.txt',
         'rb_soft_191107_s8.txt',
         'rb_soft_191207_s1.txt',
         'rb_soft_191207_s2.txt',
         'rb_soft_200317_s4.txt',
         'rb_soft_200317_s8.txt',
         'rb_soft_200723_s6.txt',
         'rb_soft_200917_s1.txt',
         'RB_201009_15K_S1_Soft.txt',
         'RB_201009_15K_S2_Soft.txt',]

sponsors = [s1_sponsor, s2_sponsor, s4_sponsor, s5_sponsor, s6_sponsor, s8_sponsor]

current_date = dt.datetime.now().strftime('%y%m%d')

df_imsi = DataFrame(columns = ['IMSI', 'KI', 'OPC'])

for file in files:
    df_imsi = df_imsi.append(pd.read_csv(join(downloads, file), sep=' ', engine='python'))

df_imsi.IMSI = df_imsi.IMSI.astype('int64')
df_imsi.sort_values(by = 'IMSI', inplace = True)

df_imsi.head(3)
# Out:
#               IMSI                                KI  \
# 0  234500026400000  693E4A067EEB7F66AD9FBD5D0AA3D1E6
# 1  234500026400001  0C12B4359E0AF6FA8D25E39C0662C3D5
# 2  234500026400002  EC3655E2752449C2E8B1F96F79F9A2FD
#
#                                 OPC
# 0  79EC10C3C95CED20C758681507904E6D
# 1  02DECFCAE2F9A6D1AED425ED810B2CA6
# 2  79798D3604C1EDF288F237963111E7FB

# %%
# Из базы данных OCS выгружаем IMSI
#----------------------------------

import pandas as pd
import pyodbc 
#Connect to OCSDBREP1 (BSS)
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER=172.18.11.82;DATABASE=10028;UID=BSS;PWD=iKQVm40AZAmyRaw72LeY')

sql_srt=\
'''
SELECT DISTINCT
r.RESELLER_NAME
,a.ACCOUNT_NAME
,ss.STATUS AS SUB_STATUS
,si.IMSI
FROM RESELLERS r
INNER JOIN ACCOUNTS a
ON r.RESELLER_ID = a.RESELLER_ID
INNER JOIN SUBSCRIBERS sr
ON sr.ACCOUNT_ID = a.ACCOUNT_ID
INNER JOIN SUBSCRIBER_STATUS ss
ON ss.SUBSCRIBER_ID = sr.SUBSCRIBER_ID
INNER JOIN SUBSCRIBER_IMSIS si
ON ss.SUBSCRIBER_ID = si.SUBSCRIBER_ID
WHERE
r.deleted is NULL
AND ss.END_DATE IS NULL
AND ss.status = 'Active'
AND
(si.IMSI BETWEEN '260060140890000' AND '260060140899999'
OR si.IMSI BETWEEN '260060149991100' AND '260060149999999'
OR si.IMSI BETWEEN '425019613998060' AND '425019613999999'
OR si.IMSI BETWEEN '425019629920000' AND '425019629939999'
OR si.IMSI BETWEEN '425019613790000' AND '425019613799999'
OR si.IMSI BETWEEN '425019613788000' AND '425019613789999'
OR si.IMSI BETWEEN '260060149982000' AND '260060149989999'
OR si.IMSI BETWEEN '454030227305000' AND '454030227305999'
OR si.IMSI BETWEEN '454030227306000' AND '454030227308999'
OR si.IMSI BETWEEN '454030227310000' AND '454030227310999'
OR si.IMSI BETWEEN '515030191000000' AND '515030191009999'
OR si.IMSI BETWEEN '425019613960000' AND '425019613989999'
OR si.IMSI BETWEEN '260060149940000' AND '260060149969999'
OR si.IMSI BETWEEN '454030227311000' AND '454030227319999'
OR si.IMSI BETWEEN '260036610100000' AND '260036610100999'
OR si.IMSI BETWEEN '234500026400000' AND '234500026400999'
OR si.IMSI BETWEEN '425019613930000' AND '425019613959999'
OR si.IMSI BETWEEN '260060149910000' AND '260060149939999'
OR si.IMSI BETWEEN '454030227615000' AND '454030227619999'
OR si.IMSI BETWEEN '234500026425000' AND '234500026434999'
OR si.IMSI BETWEEN '260036610006000' AND '260036610015999'
OR si.IMSI BETWEEN '425019613096000' AND '425019613105999'
OR si.IMSI BETWEEN '425019613165000' AND '425019613179999'
OR si.IMSI BETWEEN '260060143235000' AND '260060143249999')
'''

# OR si.IMSI BETWEEN '515030191000000' AND '515030191099999' # Full range of Smart

df_ocs_imsi = pd.read_sql_query(sql_srt, cnxn, coerce_float=False)
df_ocs_imsi['IMSI'] = df_ocs_imsi['IMSI'].astype('int64')
cnxn.close()
df_ocs_imsi.head(3)
# Out:
#   RESELLER_NAME             ACCOUNT_NAME SUB_STATUS             IMSI
# 0           1OT           Test SIM cards     Active  425019613998118
# 1           1OT           Test SIM cards     Active  454030227305015
# 2   Clementvale  Clementvale S1 profiles     Active  425019613791003

# %%
# Объединяем IMSI с ключами и данные OCS
#----------------------------------

df_ocs_imsi_ki = pd.merge(df_imsi, df_ocs_imsi, how='left', on='IMSI')
list_agg = [('IMSI_MIN','min'),('IMSI_MAX','max'),('NUM','count')]
list_col = ['RESELLER_NAME', 'ACCOUNT_NAME', 'SUB_STATUS', df_ocs_imsi_ki.IMSI.astype('str').str.slice(0,12)]
df_ocs_imsi_ki_group = df_ocs_imsi_ki.groupby(list_col)['IMSI'].agg(list_agg).reset_index().sort_values(by='IMSI')

df_ocs_imsi_ki_group.head(3)
# Out:
#                   RESELLER_NAME          ACCOUNT_NAME SUB_STATUS  \
# 353         Tottolli-Tech-Mobil      Tottolli S8 Soft     Active
# 280         Roamability Test RT  Sigos Test Sim cards     Active
# 270  Roamability Resellers Test            Ultrapower     Active
#
#              IMSI         IMSI_MIN         IMSI_MAX  NUM
# 353  234500026400  234500026400002  234500026400021   20
# 280  234500026400  234500026400000  234500026400000    1
# 270  234500026400  234500026400052  234500026400053    2

# %%
# For test accounts to use the following ranges:
# S1: 425019613998*
# S2: 260060149991*
# S4: 4540302273050*
# S5: 515030191000*
# Выбрать свободные из "Roamability Invertory"

for sponsor in sponsors:
    print(f'{sponsor.sponsor} test IMSIs in OCS by Reseller:')
    display(df_ocs_imsi_ki_group[df_ocs_imsi_ki_group['IMSI'] == sponsor.test_range].sort_values('IMSI_MIN'))
# Out:
# S1 test IMSIs in OCS by Reseller:
#                                RESELLER_NAME  \
# 26   Flexiroam Limited -- TESTING at 2018-07
# 127                              MCN Telecom
# 287                      Tottolli-Tech-Mobil
# 13                   Dialoq - Genesisclub RT
# 115                              Joy_telecom
# 356                             Watchdata SG
# 182                                RedTea RT
# 255               Roamability Resellers Test
# 1                                        1OT
# 7                                       DENT
# 6                                       DENT
# 20                                   Drimsim
# 139                              MCN Telecom
# 260               Roamability Resellers Test
# 305                      Tottolli-Tech-Mobil
# 267               Roamability Resellers Test
# 236                    Roamability Invertory
# 64                                  Freecell
# 257               Roamability Resellers Test
# 283                                    Taggs
# 263               Roamability Resellers Test
# 16                   Dialoq - Genesisclub RT
# 270               Roamability Resellers Test
# 119                         Justworks Mobile
# 282                                 Simlocal
# 285                                   Taisys
#
#                           ACCOUNT_NAME SUB_STATUS          IMSI  \
# 26         Flexiroam Test Soft simcard     Active  425019613998
# 127               MCN Telecom Soft SIM     Active  425019613998
# 287                     Test Sim cards     Active  425019613998
# 13       Genesisclub Partner Soft test     Active  425019613998
# 115      Joy telecom Partner Soft test     Active  425019613998
# 356       Watchdata  Partner Soft test     Active  425019613998
# 182  RedTea TEST Soft-simcards account     Active  425019613998
# 255                Clementvale S1 soft     Active  425019613998
# 1                       Test SIM cards     Active  425019613998
# 7                           S1Profiles     Active  425019613998
# 6                    MultiImsiProfiles     Active  425019613998
# 20           Drimsim S1 Soft test IMSI     Active  425019613998
# 139            MCN Telecom Soft SIM S1     Active  425019613998
# 260                         Myrepublic     Active  425019613998
# 305                   Tottolli S1 Soft     Active  425019613998
# 267                       Showmac Soft     Active  425019613998
# 236    Partner Soft simcards inventory     Active  425019613998
# 64                    Freecell S1 Soft     Active  425019613998
# 257                        JCI S1 Soft     Active  425019613998
# 283                           Taggs S1     Active  425019613998
# 263                        Roamwifi S1     Active  425019613998
# 16                    Truphone S1 Soft     Active  425019613998
# 270                        VTB S1 soft     Active  425019613998
# 119         Justworks S1 test soft SIM     Active  425019613998
# 282                     Test SIM cards     Active  425019613998
# 285                     Test Sim cards     Active  425019613998
#
#             IMSI_MIN         IMSI_MAX  NUM
# 26   425019613998060  425019613998064    5
# 127  425019613998065  425019613998067    3
# 287  425019613998071  425019613998081    4
# 13   425019613998072  425019613998937   18
# 115  425019613998088  425019613998929    5
# 356  425019613998090  425019613998090    1
# 182  425019613998093  425019613998491   22
# 255  425019613998113  425019613998990    6
# 1    425019613998118  425019613998119    2
# 7    425019613998120  425019613998142   12
# 6    425019613998123  425019613998132   10
# 20   425019613998153  425019613998984  324
# 139  425019613998483  425019613998949   10
# 260  425019613998488  425019613998489    2
# 305  425019613998501  425019613998520   20
# 267  425019613998521  425019613998530   10
# 236  425019613998531  425019613998900  370
# 64   425019613998901  425019613998913   13
# 257  425019613998930  425019613998931    2
# 283  425019613998938  425019613998940    3
# 263  425019613998941  425019613998942    2
# 16   425019613998960  425019613998989   25
# 270  425019613998991  425019613998994    4
# 119  425019613998995  425019613998995    1
# 282  425019613998996  425019613998996    1
# 285  425019613998997  425019613998999    3
# S2 test IMSIs in OCS by Reseller:
#                                RESELLER_NAME                 ACCOUNT_NAME  \
# 25   Flexiroam Limited -- TESTING at 2018-07  Flexiroam Test Soft simcard
# 126                              MCN Telecom         MCN Telecom Soft SIM
# 12                   Dialoq - Genesisclub RT     Genesisclub P4 Soft test
# 357                             Watchdata SG       Watchdata P4 Soft test
# 22                                   Drimsim    Drimsim S2 Soft test IMSI
# 0                                        1OT               Test SIM cards
# 8                                       DENT                   S2Profiles
# 5                                       DENT            MultiImsiProfiles
# 262               Roamability Resellers Test              PointDume Multi
# 146                              MCN Telecom      MCN Telecom Soft SIM S2
# 277                      Roamability Test RT         Sigos Test Sim cards
# 259               Roamability Resellers Test                   Myrepublic
# 326                      Tottolli-Tech-Mobil             Tottolli S2 Soft
# 266               Roamability Resellers Test                 Showmac Soft
# 272                      Roamability Test RT                        Oasis
# 208                    Roamability Invertory   P4 Soft simcards inventory
# 100                                 Freecell             Freecell S2 Soft
# 114                              Joy_telecom     Joy telecom P4 Soft test
# 258               Roamability Resellers Test                  JCI S2 Soft
# 264               Roamability Resellers Test                  Roamwifi S2
# 17                   Dialoq - Genesisclub RT             Truphone S2 Soft
# 256               Roamability Resellers Test          Clementvale S2 soft
# 120                         Justworks Mobile   Justworks S2 test soft SIM
# 281                                 Simlocal               Test SIM cards
# 284                                   Taisys               Test Sim cards
#
#     SUB_STATUS          IMSI         IMSI_MIN         IMSI_MAX  NUM
# 25      Active  260060149991  260060149991100  260060149991104    5
# 126     Active  260060149991  260060149991105  260060149991107    3
# 12      Active  260060149991  260060149991110  260060149991945   18
# 357     Active  260060149991  260060149991123  260060149991123    1
# 22      Active  260060149991  260060149991124  260060149991949   12
# 0       Active  260060149991  260060149991135  260060149991135    1
# 8       Active  260060149991  260060149991136  260060149991158   12
# 5       Active  260060149991  260060149991138  260060149991478   21
# 262     Active  260060149991  260060149991479  260060149991498   20
# 146     Active  260060149991  260060149991499  260060149991954   10
# 277     Active  260060149991  260060149991504  260060149991504    1
# 259     Active  260060149991  260060149991505  260060149991506    2
# 326     Active  260060149991  260060149991517  260060149991536   20
# 266     Active  260060149991  260060149991537  260060149991546   10
# 272     Active  260060149991  260060149991547  260060149991547    1
# 208     Active  260060149991  260060149991548  260060149991908  361
# 100     Active  260060149991  260060149991909  260060149991921   13
# 114     Active  260060149991  260060149991937  260060149991996    3
# 258     Active  260060149991  260060149991938  260060149991939    2
# 264     Active  260060149991  260060149991946  260060149991947    2
# 17      Active  260060149991  260060149991965  260060149991991   25
# 256     Active  260060149991  260060149991992  260060149991992    1
# 120     Active  260060149991  260060149991993  260060149991993    1
# 281     Active  260060149991  260060149991994  260060149991994    1
# 284     Active  260060149991  260060149991997  260060149991999    3
# S4 test IMSIs in OCS by Reseller:
#                   RESELLER_NAME               ACCOUNT_NAME SUB_STATUS  \
# 2                           1OT             Test SIM cards     Active
# 23                      Drimsim  Drimsim S4 Soft test IMSI     Active
# 278         Roamability Test RT       Sigos Test Sim cards     Active
# 261  Roamability Resellers Test                 Myrepublic     Active
# 332         Tottolli-Tech-Mobil           Tottolli S4 Soft     Active
# 268  Roamability Resellers Test               Showmac Soft     Active
# 11      Dialoq - Genesisclub RT            Dailoq S2+S1+S4     Active
#
#              IMSI         IMSI_MIN         IMSI_MAX  NUM
# 2    454030227305  454030227305015  454030227305016    2
# 23   454030227305  454030227305117  454030227305141   25
# 278  454030227305  454030227305142  454030227305142    1
# 261  454030227305  454030227305143  454030227305144    2
# 332  454030227305  454030227305145  454030227305349  195
# 268  454030227305  454030227305165  454030227305174   10
# 11   454030227305  454030227305350  454030227305499  150
# S5 test IMSIs in OCS by Reseller:
#                          RESELLER_NAME                   ACCOUNT_NAME  \
# 24                             Drimsim      Drimsim S5 Soft test IMSI
# 118                        Joy_telecom            Joy telecom S5 Soft
# 274                Roamability Test RT       RedTea S5 Test SIM cards
# 279                Roamability Test RT           Sigos Test Sim cards
# 167                    Mondicon SIM RT               S5 soft profiles
# 338                Tottolli-Tech-Mobil               Tottolli S5 Soft
# 18             Dialoq - Genesisclub RT               Truphone S5 Soft
# 269         Roamability Resellers Test                   Showmac Soft
# 271                Roamability Test RT                         DID's
# 280  Roamability Test SMART Sponsor RT         Roamability Test SMART
# 251              Roamability Invertory  Smart Soft Profiles inventory
#
#     SUB_STATUS          IMSI         IMSI_MIN         IMSI_MAX  NUM
# 24      Active  515030191000  515030191000000  515030191000024   25
# 118     Active  515030191000  515030191000025  515030191000034   10
# 274     Active  515030191000  515030191000035  515030191000035    1
# 279     Active  515030191000  515030191000036  515030191000036    1
# 167     Active  515030191000  515030191000037  515030191000056   20
# 338     Active  515030191000  515030191000057  515030191000756  570
# 18      Active  515030191000  515030191000077  515030191000096   20
# 269     Active  515030191000  515030191000097  515030191000106   10
# 271     Active  515030191000  515030191000107  515030191000206  100
# 280     Active  515030191000  515030191000757  515030191000760    4
# 251     Active  515030191000  515030191000761  515030191000999  239
# S6 test IMSIs in OCS by Reseller:
#              RESELLER_NAME                ACCOUNT_NAME SUB_STATUS  \
# 276    Roamability Test RT        Sigos Test Sim cards     Active
# 273    Roamability Test RT       Orange Test Sim cards     Active
# 347    Tottolli-Tech-Mobil            Tottolli S6 Soft     Active
# 245  Roamability Invertory  S6 Soft Profiles inventory     Active
#
#              IMSI         IMSI_MIN         IMSI_MAX  NUM
# 276  260036610100  260036610100000  260036610100000    1
# 273  260036610100  260036610100001  260036610100111    6
# 347  260036610100  260036610100003  260036610100107  105
# 245  260036610100  260036610100112  260036610100999  888
# S8 test IMSIs in OCS by Reseller:
#                   RESELLER_NAME                ACCOUNT_NAME SUB_STATUS  \
# 275         Roamability Test RT        Sigos Test Sim cards     Active
# 348         Tottolli-Tech-Mobil            Tottolli S8 Soft     Active
# 19      Dialoq - Genesisclub RT            Truphone S8 Soft     Active
# 265  Roamability Resellers Test                Showmac Soft     Active
# 246       Roamability Invertory  S8 Soft Profiles inventory     Active
#
#              IMSI         IMSI_MIN         IMSI_MAX  NUM
# 275  234500026400  234500026400000  234500026400000    1
# 348  234500026400  234500026400002  234500026400021   20
# 19   234500026400  234500026400022  234500026400041   20
# 265  234500026400  234500026400042  234500026400051   10
# 246  234500026400  234500026400052  234500026400999  948

# %%
# For commersial usage

for sponsor in sponsors:
    print(f'{sponsor.sponsor} prod IMSIs in OCS by Reseller:')
    display(df_ocs_imsi_ki_group[(df_ocs_imsi_ki_group.IMSI.str.startswith(sponsor.prod_range, na=False))
                                 & (df_ocs_imsi_ki_group.RESELLER_NAME == 'Roamability Invertory')
                                ].sort_values('IMSI_MIN'))
# Out:
# S1 prod IMSIs in OCS by Reseller:
#              RESELLER_NAME                     ACCOUNT_NAME SUB_STATUS  \
# 233  Roamability Invertory  Partner Soft simcards inventory     Active
# 234  Roamability Invertory  Partner Soft simcards inventory     Active
# 235  Roamability Invertory  Partner Soft simcards inventory     Active
# 236  Roamability Invertory  Partner Soft simcards inventory     Active
# 237  Roamability Invertory  Partner Soft simcards inventory     Active
#
#              IMSI         IMSI_MIN         IMSI_MAX   NUM
# 233  425019613987  425019613987000  425019613987999  1000
# 234  425019613988  425019613988000  425019613988999  1000
# 235  425019613989  425019613989000  425019613989999  1000
# 236  425019613998  425019613998531  425019613998900   370
# 237  425019613999  425019613999750  425019613999997   248
# S2 prod IMSIs in OCS by Reseller:
#              RESELLER_NAME                ACCOUNT_NAME SUB_STATUS  \
# 224  Roamability Invertory  P4 Soft simcards inventory     Active
# 225  Roamability Invertory  P4 Soft simcards inventory     Active
# 226  Roamability Invertory  P4 Soft simcards inventory     Active
# 227  Roamability Invertory  P4 Soft simcards inventory     Active
# 228  Roamability Invertory  P4 Soft simcards inventory     Active
# 229  Roamability Invertory  P4 Soft simcards inventory     Active
# 230  Roamability Invertory  P4 Soft simcards inventory     Active
#
#              IMSI         IMSI_MIN         IMSI_MAX   NUM
# 224  260060149956  260060149956500  260060149956999   500
# 225  260060149965  260060149965000  260060149965999  1000
# 226  260060149966  260060149966000  260060149966999  1000
# 227  260060149967  260060149967000  260060149967999  1000
# 228  260060149991  260060149991548  260060149991908   361
# 229  260060149992  260060149992000  260060149992999  1000
# 230  260060149999  260060149999750  260060149999992   243
# S4 prod IMSIs in OCS by Reseller:
#              RESELLER_NAME                         ACCOUNT_NAME SUB_STATUS  \
# 223  Roamability Invertory  Multi Byte Soft Profiles Inventory      Active
# 231  Roamability Invertory           P4 Soft simcards inventory     Active
# 232  Roamability Invertory           P4 Soft simcards inventory     Active
#
#              IMSI         IMSI_MIN         IMSI_MAX   NUM
# 223  454030227306  454030227306675  454030227306999   325
# 231  454030227618  454030227618000  454030227618999  1000
# 232  454030227619  454030227619000  454030227619999  1000
# S5 prod IMSIs in OCS by Reseller:
#              RESELLER_NAME                   ACCOUNT_NAME SUB_STATUS  \
# 251  Roamability Invertory  Smart Soft Profiles inventory     Active
# 252  Roamability Invertory  Smart Soft Profiles inventory     Active
# 253  Roamability Invertory  Smart Soft Profiles inventory     Active
# 254  Roamability Invertory  Smart Soft Profiles inventory     Active
#
#              IMSI         IMSI_MIN         IMSI_MAX   NUM
# 251  515030191000  515030191000761  515030191000999   239
# 252  515030191001  515030191001300  515030191001999   700
# 253  515030191008  515030191008000  515030191008999  1000
# 254  515030191009  515030191009000  515030191009999  1000
# S6 prod IMSIs in OCS by Reseller:
#              RESELLER_NAME                ACCOUNT_NAME SUB_STATUS  \
# 238  Roamability Invertory  S6 Soft Profiles inventory     Active
# 239  Roamability Invertory  S6 Soft Profiles inventory     Active
# 240  Roamability Invertory  S6 Soft Profiles inventory     Active
# 241  Roamability Invertory  S6 Soft Profiles inventory     Active
# 242  Roamability Invertory  S6 Soft Profiles inventory     Active
# 243  Roamability Invertory  S6 Soft Profiles inventory     Active
# 244  Roamability Invertory  S6 Soft Profiles inventory     Active
# 245  Roamability Invertory  S6 Soft Profiles inventory     Active
#
#              IMSI         IMSI_MIN         IMSI_MAX   NUM
# 238  260036610009  260036610009000  260036610009999  1000
# 239  260036610010  260036610010000  260036610010999  1000
# 240  260036610011  260036610011000  260036610011999  1000
# 241  260036610012  260036610012000  260036610012999  1000
# 242  260036610013  260036610013000  260036610013999  1000
# 243  260036610014  260036610014000  260036610014999  1000
# 244  260036610015  260036610015000  260036610015999  1000
# 245  260036610100  260036610100112  260036610100999   888
# S8 prod IMSIs in OCS by Reseller:
#              RESELLER_NAME                ACCOUNT_NAME SUB_STATUS  \
# 246  Roamability Invertory  S8 Soft Profiles inventory     Active
# 247  Roamability Invertory  S8 Soft Profiles inventory     Active
# 248  Roamability Invertory  S8 Soft Profiles inventory     Active
# 249  Roamability Invertory  S8 Soft Profiles inventory     Active
# 250  Roamability Invertory  S8 Soft Profiles inventory     Active
#
#              IMSI         IMSI_MIN         IMSI_MAX   NUM
# 246  234500026400  234500026400052  234500026400999   948
# 247  234500026426  234500026426550  234500026426999   450
# 248  234500026432  234500026432000  234500026432999  1000
# 249  234500026433  234500026433000  234500026433999  1000
# 250  234500026434  234500026434000  234500026434999  1000

# %%
# Записать выбранные диапазоны IMSI
# Проверить выбранные IMSI на принадлежность к "Roamability Invertory"

# После переноса IMSI в аккаунты Кастомеров проверить выбранные IMSI и диапазоны
# (предварительно перезагрузив данные из OCS)

imsi_range_object = namedtuple('ImsiRange', 'sponsor imsi_list')

def imsi_list(range_start, range_end):
    return [str(imsi) for imsi in range(range_start, range_end+1,1)]

### Set the IMSI ranges here ###

# s1_imsi_range = imsi_range_object('S1', imsi_list(425019613175000, 425019613179999))
# s2_imsi_range = imsi_range_object('S2', imsi_list(260060143245000, 260060143249999))
s1_imsi_range = imsi_range_object('S1', imsi_list(425019613998531, 425019613998531+1))
s2_imsi_range = imsi_range_object('S2', imsi_list(260060149991548, 260060149991548+1))
s4_imsi_range = imsi_range_object('S4', imsi_list(0, 0))
s5_imsi_range = imsi_range_object('S5', imsi_list(515030191000761, 515030191000761+1))
s6_imsi_range = imsi_range_object('S6', imsi_list(260036610100112, 260036610100112+1))
s8_imsi_range = imsi_range_object('S8', imsi_list(234500026400052, 234500026400052+1))

#################################

imsi_ranges = [s1_imsi_range, s2_imsi_range, s4_imsi_range, s5_imsi_range, s6_imsi_range, s8_imsi_range]

for imsi_range in imsi_ranges:
    if imsi_range.imsi_list:
        display(df_ocs_imsi[df_ocs_imsi.IMSI.astype('str').isin(imsi_range.imsi_list)].groupby(['RESELLER_NAME',
                                                                                'ACCOUNT_NAME','SUB_STATUS']).count())
# Out:
#                                                     IMSI
# RESELLER_NAME              ACCOUNT_NAME SUB_STATUS
# Roamability Resellers Test Ultrapower   Active         2
#                                                     IMSI
# RESELLER_NAME              ACCOUNT_NAME SUB_STATUS
# Roamability Resellers Test Ultrapower   Active         2
# Empty DataFrame
# Columns: [IMSI]
# Index: []
#                                                     IMSI
# RESELLER_NAME              ACCOUNT_NAME SUB_STATUS
# Roamability Resellers Test Ultrapower   Active         2
#                                                     IMSI
# RESELLER_NAME              ACCOUNT_NAME SUB_STATUS
# Roamability Resellers Test Ultrapower   Active         2
#                                                     IMSI
# RESELLER_NAME              ACCOUNT_NAME SUB_STATUS
# Roamability Resellers Test Ultrapower   Active         2

# %%
# Выгружаем файлы с ключами для диапазонов IMSI
#----------------------------------

for sponsor, imsi_range in zip(sponsors, imsi_ranges):
    if sponsor.account_name and imsi_range.imsi_list:
        df_ocs_imsi_ki.loc[(df_ocs_imsi_ki.RESELLER_NAME == reseller_name)
                           & (df_ocs_imsi_ki.ACCOUNT_NAME == sponsor.account_name)
                           & (df_ocs_imsi_ki.IMSI.astype('str').isin(imsi_range.imsi_list)),
                           ['IMSI', 'KI', 'OPC']].\
        to_csv(join(downloads, f'{sponsor.sponsor}_{customer_name}_{current_date}.txt'), index=False)
        print(f'{sponsor.sponsor}_{customer_name}_{current_date}.txt')
# Out:
# S1_Ultrapower_201114.txt
# S2_Ultrapower_201114.txt
# S5_Ultrapower_201114.txt
# S6_Ultrapower_201114.txt
# S8_Ultrapower_201114.txt

# %% [markdown]
# ### Далее шифруем и отправляем
# ----------------------------------
# 1. Упаковать оба файла в zip архив.
# 2. Выполнить экспорт открытого ключа Кастомера (дважды кликнуть по файлу ключа).
# 3. В папке с архивом по пр.кл. на zip архив и выбрать "Зашифровать"
# 4. Зашифровать своим ключем *_FOR_KEYS
# 5. Отправить кастомеру. Свой ключ отправлять не нужно.

# %% [markdown]
# ### Developments

# %%
df_imsi.loc[df_imsi.IMSI == 260060149999626]
# Out:
#                  IMSI                                KI  \
# 8526  260060149999626  488BD7697DE1BE5DC40D0974A5C41DC9
#
#                                    OPC
# 8526  B595F1345C080760BB7CEDBD4B0275D6
