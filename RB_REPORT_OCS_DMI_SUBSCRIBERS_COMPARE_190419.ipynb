# %% [markdown]
# ## Method of comparing DMI and OCS subscribers

# %% [markdown]
# SQL DMI Request
#
# si.FLAG_CONFIRMED - null mean confirmed
#
# SELECT m.NAME AS MVNO_NAME
# ,s.IMSI,s.MSISDN
# ,si.IMSI_NUMBER AS S_IMSI,si.PROF_ID
# ,sp.NAME AS SP_NAME
# ,s.SIM_APP_VER
# ,ASCII(si.FLAG_CONFIRMED) AS FLAG
# FROM
# SUBSCRIBER s, MVNO m, S_IMSI si, SPONSOR sp
# WHERE s.MVNO_REF = m.RI
# AND s.RI = si.SUBSCRIBER_REF
# AND sp.RI = si.SPONSOR_REF
# --AND ROWNUM <= 1000
# ORDER BY m.NAME,s.IMSI,si.PROF_ID

# %%
from os.path import join
import pandas as pd
from pandas import Series, DataFrame
import roamability as rb
import numpy as np

downloads = r'c:\Users\balob\Downloads\REPORT_OCS_DMI_SUBSCRIBERS_COMPARE'
dmi_subs_file_name = 'export_dmi_subs_190423.csv'
ocs_subs_file_name = 'export_ocs_subs_190423.csv'

dict_dmi_flag = {'0': 'Confirmed'
                ,np.nan: 'Confirmed'
                ,'1': 'Not confirmed'
                ,'2': 'Disconnected'}

list_sponsor = [
    ['Cellact','P4_Combined','S2','Combined'],
    ['Cellact','Partner_Combined','S1','Combined'],
    ['Citictell','P4_Combined','S2','Combined'],
    ['Citictell','Partner_Combined','S1','Combined'],
    ['Clay','P4_Clay_Combined','S2','ClayCombined'],
    ['Clay','Partner_Clay_Com','S1','ClayCombined'],
    ['Maxcom','P4_Combined','S2','Combined'],
    ['Maxcom','Partner_Combined','S1','Combined'],
    ['Mobileye','P4_BLOCK','S2','MobileyeCombined'],
    ['Mobileye','Partner_mobileye','S1','MobileyeCombined'],
    ['Mondicon','P4_mon-sky','S2','MondiconMonSky'],
    ['Mondicon','P4_mon_Russia','S2','MondiconMonRus'],
    ['Mondicon','P4_mon_bss','S2','MondiconMonBss'],
    ['Mondicon','P4_mon_euro','S2','MondiconMonEuro'],
    ['Mondicon','P4_mon_world','S2','MondiconMonWorld'],
    ['Mondicon','P4_mondic','S2','MondiconCombined'],
    ['Mondicon','Partner_mon-sky','S1','MondiconMonSky'],
    ['Mondicon','Partner_mon_bss','S1','MondiconMonBss'],
    ['Mondicon','Partner_mon_euro','S1','MondiconMonEuro'],
    ['Mondicon','Partner_mon_rus','S1','MondiconMonRus'],
    ['Mondicon','Partner_mon_worl','S1','MondiconMonWorld'],
    ['Mondicon','Partner_mondic','S1','MondiconCombined'],
    ['Nextel','P4_Combined','S2','Combined'],
    ['Nextel','Partner_Combined','S1','Combined'],
    ['Nextel','Partner_CombNext','S1','NextelCombined'],
    ['Nextel','P4_Comb_Nextel','S2','NextelCombined'],
    ['PuertoSeguro','P4_PS','S2','PuertoSeguroCombined'],
    ['PuertoSeguro','Partner_PS','S1','PuertoSeguroCombined'],
    ['RUSEC','P4_Combined','S2','Combined'],
    ['RUSEC','Partner_Combined','S1','Combined'],
    ['RedT_Partner_Sof','Partner_RedT_Sof','S1','RedTeaPartnerSoft'],
    ['Rewicom','P4_Combined','S2','Combined'],
    ['Rewicom','Partner_Combined','S1','Combined'],
    ['STI','P4_STI_Comb','S2','StiCombined'],
    ['STI','P4_STI_Ping','S2','StiCombinedPing'],
    ['STI','Partner_STI_Comb','S1','StiCombined'],
    ['STI','Partner_STI_Ping','S1','StiCombinedPing'],
    ['TATTELECOM','P4_Combined','S2','Combined'],
    ['TATTELECOM','Partner_Combined','S1','Combined'],
    ['TECHMOB','P4_Combined','S2','Combined'],
    ['TECHMOB','Partner_Combined','S1','Combined'],
    ['Telzar','P4_telzar','S2','TelzarCombined'],
    ['Telzar','PA_Telzar_Soft','S1','TelzarS1Soft'],
    ['Telzar','Partner_telzar','S1','TelzarCombined'],
    ['Telzar_Soft','PA_Telzar_Soft','S1','TelzarS1Soft'],
    ['Tinklabs','P4_tinklabs','S2','TinklabsCombined'],
    ['Tinklabs','Partner_tinklabs','S1','TinklabsCombined'],
    ['WMB_Combined','P4_WMB_Combined','S2','WmbCombined'],
    ['WMB_Combined','Partner_WMB_Comb','S1','WmbCombined'],
    ['Roamability','P4_Combined','S2','Combined'],
    ['Roamability','Partner_Combined','S1','Combined'],
    ['Roamability','Partner_All','S1','RoamabilityS1Soft'],
    ['Roamability','P4_All','S2','RoamabilityS2Soft'],
    ['Partner_Joy_Soft','Partner_Joy_All','S1','JoyS1Soft'],
    ['TECHMOB','P4_All','S2','TechmobS2Soft'],
    ['TECHMOB','Partner_All','S1','TechmobS1Soft'],
    ['Roamability','P4_WeStream','S2','WeStreamS2Soft'],
    ['Roamability','Partner_WeStream','S1','WeStreamS1Soft'],
]

df_prof_book = DataFrame(list_sponsor, columns=['MVNO_NAME', 'SP_NAME', 'SPONSOR', 'PROFILE'])

def print_raw_data(imsi):
    print('Данные DMI:')
    display(df_dmi[df_dmi.IMSI == imsi])
    print('Данные OCS:')
    display(df_ocs[df_ocs.IMSI == imsi])
    print('Объединенные данные DMI и OCS:')
    display(df_ocs_dmi[df_ocs_dmi.IMSI == imsi])

# %% [markdown]
# ### Получить данные DMI из файла

# %%
df_dmi = pd.read_csv(join(downloads, dmi_subs_file_name), dtype='str')
df_dmi.FLAG.fillna('0', inplace=True)
df_dmi.FLAG.replace(dict_dmi_flag, inplace=True)
df_dmi.loc[df_dmi.FLAG == ''] = 'Missing'

df_dmi.head(3)
# Out:
#   MVNO_NAME             IMSI        MSISDN           S_IMSI PROF_ID  \
# 0   Cellact  425180020000000  972557012345  425019620010108       1
# 1   Cellact  425180020000000  972557012345  260060140068752       2
# 2   Cellact  425180020000002           NaN  425019620011335       1
#
#             SP_NAME SIM_APP_VER          FLAG
# 0  Partner_Combined           7     Confirmed
# 1       P4_Combined           7     Confirmed
# 2  Partner_Combined           7  Disconnected

# %%
df_dmi.dtypes
# Out:
# MVNO_NAME      object
# IMSI           object
# MSISDN         object
# S_IMSI         object
# PROF_ID        object
# SP_NAME        object
# SIM_APP_VER    object
# FLAG           object
# dtype: object

# %% [markdown]
# ### Получить данные OCS

# %%
# Получить абонентов OCS (из базы данных)

sql_srt='''
SELECT r.RESELLER_NAME
,a.ACCOUNT_NAME
,si.IMSI
,mi.IMSI AS S_IMSI
,ss.STATUS, ss.START_DATE
,s.subscriber_id AS SUBSCRIBER_ID
FROM SUBSCRIBER_IMSIS si
LEFT JOIN MULTI_IMSI mi ON si.subscriber_id = mi.subscriber_id
LEFT JOIN SUBSCRIBER_STATUS ss ON si.subscriber_id = ss.subscriber_id
LEFT JOIN SUBSCRIBERS s ON si.subscriber_id = s.subscriber_id
LEFT JOIN ACCOUNTS a ON a.account_id = s.account_id
LEFT JOIN RESELLERS r ON r.reseller_id = a.reseller_id
WHERE ss.END_DATE IS NULL
AND mi.END_DATE IS NULL
'''

with rb.MssqlConnect('172.18.11.82', '10028', 'BSS', 'iKQVm40AZAmyRaw72LeY') as cnxn: # prod connection
    df_ocs = pd.read_sql_query(sql_srt, cnxn, coerce_float=False)
df_ocs.head(3)
# Out:
#          RESELLER_NAME          ACCOUNT_NAME             IMSI  \
# 0  Porto Seguro DMI RT  Porto Seguro Conecta  724540540263237
# 1  Porto Seguro DMI RT  Porto Seguro Conecta  724540540263250
# 2  Porto Seguro DMI RT  Porto Seguro Conecta  724540540263257
#
#             S_IMSI  STATUS              START_DATE SUBSCRIBER_ID
# 0  425019620000023  Active 2016-09-21 00:19:07.907        195602
# 1  425019620000025  Active 2016-09-21 16:50:24.880        195604
# 2  425019620000031  Active 2016-09-29 21:49:12.187        195609

# %%
# Сохранить данные абонентов OCS в файл

df_ocs.to_csv(join(downloads, ocs_subs_file_name), index=False)

# %%
# Получить абонентов OCS (из файла)

#df_ocs = pd.read_csv(join(downloads, ocs_subs_file_name), dtype='str')
#df_ocs.head(3)
# Out:
#        RESELLER_NAME            ACCOUNT_NAME             IMSI  \
# 0  Telzar 019 DMI RT  019 Production Account  425191201070391
# 1  Telzar 019 DMI RT  019 Production Account  425191201070392
# 2  Telzar 019 DMI RT  019 Production Account  425191201070393
#
#             S_IMSI  STATUS               START_DATE SUBSCRIBER_ID
# 0  425019629808689  Active  2017-07-14 00:22:40.250        250023
# 1  425019629808690  Active  2017-07-14 00:22:40.310        250024
# 2  425019629808691  Active  2017-07-14 00:22:40.360        250025

# %%
df_ocs.dtypes
# Out:
# RESELLER_NAME            object
# ACCOUNT_NAME             object
# IMSI                     object
# S_IMSI                   object
# STATUS                   object
# START_DATE       datetime64[ns]
# SUBSCRIBER_ID            object
# dtype: object

# %% [markdown]
# ### Объединить и подготовить данные OCS и DMI

# %%
list_ocs_status = ['Active', 'Suspended', 'Manually Suspended', 'Auto Suspended', 'Pending', 'Activation Failed']

df_ocs_dmi = pd.merge(df_dmi[df_dmi.MSISDN.notnull()], df_ocs[df_ocs.STATUS.isin(list_ocs_status)],
                      how='outer', on=['IMSI', 'S_IMSI'])
df_ocs_dmi.head(3)
# Out:
#   MVNO_NAME             IMSI        MSISDN           S_IMSI PROF_ID  \
# 0   Cellact  425180020000000  972557012345  425019620010108       1
# 1   Cellact  425180020000000  972557012345  260060140068752       2
# 2   Cellact  425180020000004  972523726464  425019620012943       1
#
#             SP_NAME SIM_APP_VER       FLAG RESELLER_NAME  \
# 0  Partner_Combined           7  Confirmed       Cellact
# 1       P4_Combined           7  Confirmed       Cellact
# 2  Partner_Combined           7  Confirmed       Cellact
#
#              ACCOUNT_NAME  STATUS              START_DATE SUBSCRIBER_ID
# 0  Cellact Test sim cards  Active 2018-12-03 09:34:31.007       1449894
# 1  Cellact Test sim cards  Active 2018-12-03 09:34:31.007       1449894
# 2  Cellact Test sim cards  Active 2019-02-26 15:10:45.367       1552817

# %% [markdown]
# ### Анализ Case 1. DMI-y; OCS-n

# %%
# Case 1. DMI-y; OCS-n

df_ocs_n = df_ocs_dmi[(df_ocs_dmi.STATUS.isnull())]
df_ocs_n.head(3)
# Out:
#         MVNO_NAME             IMSI        MSISDN           S_IMSI PROF_ID  \
# 160033     Telzar  425191200959682  972559997281  260060149000082       2
# 512325     Telzar  425191201545375  972559736800  260060140106704       2
# 1075328    Telzar  425191202162739  972550391740  260060140106687       2
#
#            SP_NAME SIM_APP_VER       FLAG RESELLER_NAME ACCOUNT_NAME STATUS  \
# 160033   P4_telzar           6  Confirmed           NaN          NaN    NaN
# 512325   P4_telzar           6  Confirmed           NaN          NaN    NaN
# 1075328  P4_telzar           7  Confirmed           NaN          NaN    NaN
#
#         START_DATE SUBSCRIBER_ID
# 160033         NaT           NaN
# 512325         NaT           NaN
# 1075328        NaT           NaN

# %%
df_ocs_n.MVNO_NAME.value_counts()
# Out:
# Telzar    3
# Name: MVNO_NAME, dtype: int64

# %%
df = df_ocs_n[(df_ocs_n.MVNO_NAME == 'Telzar')].copy()
df
# Out:
#         MVNO_NAME             IMSI        MSISDN           S_IMSI PROF_ID  \
# 160033     Telzar  425191200959682  972559997281  260060149000082       2
# 512325     Telzar  425191201545375  972559736800  260060140106704       2
# 1075328    Telzar  425191202162739  972550391740  260060140106687       2
#
#            SP_NAME SIM_APP_VER       FLAG RESELLER_NAME ACCOUNT_NAME STATUS  \
# 160033   P4_telzar           6  Confirmed           NaN          NaN    NaN
# 512325   P4_telzar           6  Confirmed           NaN          NaN    NaN
# 1075328  P4_telzar           7  Confirmed           NaN          NaN    NaN
#
#         START_DATE SUBSCRIBER_ID
# 160033         NaT           NaN
# 512325         NaT           NaN
# 1075328        NaT           NaN

# %%
print_raw_data('425191202162739')
# Out:
# Данные DMI:
#         MVNO_NAME             IMSI        MSISDN           S_IMSI PROF_ID  \
# 1094127    Telzar  425191202162739  972550391740  425019628011739       1
# 1094128    Telzar  425191202162739  972550391740  260060140106687       2
#
#                 SP_NAME SIM_APP_VER       FLAG
# 1094127  Partner_telzar           7  Confirmed
# 1094128       P4_telzar           7  Confirmed
# Данные OCS:
#             RESELLER_NAME            ACCOUNT_NAME             IMSI  \
# 953805  Telzar 019 DMI RT  019 Production Account  425191202162739
#
#                  S_IMSI  STATUS              START_DATE SUBSCRIBER_ID
# 953805  425019628011739  Active 2018-08-12 14:28:50.497       1213892
# Объединенные данные DMI и OCS:
#         MVNO_NAME             IMSI        MSISDN           S_IMSI PROF_ID  \
# 1075327    Telzar  425191202162739  972550391740  425019628011739       1
# 1075328    Telzar  425191202162739  972550391740  260060140106687       2
#
#                 SP_NAME SIM_APP_VER       FLAG      RESELLER_NAME  \
# 1075327  Partner_telzar           7  Confirmed  Telzar 019 DMI RT
# 1075328       P4_telzar           7  Confirmed                NaN
#
#                    ACCOUNT_NAME  STATUS              START_DATE SUBSCRIBER_ID
# 1075327  019 Production Account  Active 2018-08-12 14:28:50.497       1213892
# 1075328                     NaN     NaN                     NaT           NaN

# %%
# Выгрузить проблемных абонентов

df_ocs_dmi[df_ocs_dmi.IMSI.isin(df_ocs_n.IMSI.values)
          ].sort_values(by=['MVNO_NAME', 'IMSI']).to_csv(join(downloads, 'OcsMissingImsi.csv'), index=False)

# %% [markdown]
# ### Методика решения проблемы Case 1. DMI-y; OCS-n

# %%
# Выгрузить необходимые данные из OCS

sql_srt='''
SELECT
si.subscriber_id, si.IMSI, COUNT(*) AS NUM
FROM SUBSCRIBER_IMSIS si
LEFT JOIN MULTI_IMSI mi ON si.subscriber_id=mi.subscriber_id
LEFT JOIN SUBSCRIBER_STATUS ss ON si.subscriber_id = ss.subscriber_id
WHERE ss.STATUS = 'Active' AND ss.END_DATE IS NULL
AND si.imsi IN ('''\
+ str(df_ocs_n[(df_ocs_n.MVNO_NAME == 'Telzar') & (df_ocs_n.SP_NAME == 'P4_telzar')].IMSI.tolist())[1:-1]\
+ ') GROUP BY si.subscriber_id, si.imsi HAVING COUNT(*) = 1'

with rb.MssqlConnect('172.18.11.82', '10028', 'BSS', 'iKQVm40AZAmyRaw72LeY') as cnxn: # prod connection
    df = pd.read_sql_query(sql_srt, cnxn, coerce_float=False)

pd.merge(df_ocs_n[(df_ocs_n.MVNO_NAME == 'Telzar') & (df_ocs_n.SP_NAME == 'P4_telzar')], df, how='inner', on='IMSI')
# Out:
#   MVNO_NAME             IMSI        MSISDN           S_IMSI PROF_ID  \
# 0    Telzar  425191202103584  972506839259  260060140093145       2
# 1    Telzar  425191202251043  972552451521  260060140090997       2
# 2    Telzar  425191202277272  972552478089  260060140091934       2
#
#      SP_NAME SIM_APP_VER RESELLER_NAME ACCOUNT_NAME STATUS START_DATE  \
# 0  P4_telzar           7           NaN          NaN    NaN        NaT
# 1  P4_telzar           7           NaN          NaN    NaN        NaT
# 2  P4_telzar           7           NaN          NaN    NaN        NaT
#
#   subscriber_id  NUM
# 0       1155237    1
# 1       1348001    1
# 2       1374230    1

# %%
pd.merge(df_ocs_n[(df_ocs_n.MVNO_NAME == 'Telzar') & (df_ocs_n.SP_NAME == 'P4_telzar')], df, how='inner', on='IMSI')\
[['subscriber_id','IMSI','S_IMSI','MVNO_NAME']].to_csv(join(downloads,'Case1.csv'), index=False)

# %%
# Далее по методике c:\W_DATA_ROAM\ПРОЕКТЫ\REPORT_OCS_DMI_SUBSCRIBERS_COMPARE\FIX_MISSED_P4_IMSI\

# %%
# Case 1. DMI-y; OCS-n. У абонента нет в OCS ни доного IMSI (частный случай)

df_ocs_dmi[(df_ocs_dmi.IMSI.notnull()) & (df_ocs_dmi.S_IMSI.isnull())].head()
# Out:
# Empty DataFrame
# Columns: [MVNO_NAME, IMSI, MSISDN, S_IMSI, PROF_ID, SP_NAME, SIM_APP_VER, FLAG, RESELLER_NAME, ACCOUNT_NAME, STATUS, START_DATE, SUBSCRIBER_ID]
# Index: []

# %% [markdown]
# ### Анализ Case 2. DMI-n; OCS-y

# %%
# Case 2. DMI-n; OCS-y

df_dmi_n = df_ocs_dmi[(df_ocs_dmi.IMSI.notnull()) & (df_ocs_dmi.MVNO_NAME.isnull())]
df_dmi_n.head(3)
# Out:
#         MVNO_NAME                  IMSI MSISDN           S_IMSI PROF_ID  \
# 1416870       NaN  99999425019620000102    NaN  425019620000102     NaN
# 1416871       NaN  99999425019620000104    NaN  425019620000104     NaN
# 1416872       NaN  99999425019620000105    NaN  425019620000105     NaN
#
#         SP_NAME SIM_APP_VER FLAG RESELLER_NAME             ACCOUNT_NAME  \
# 1416870     NaN         NaN  NaN   Cloud 9 TAP  Cloud 9 DMI Subscribers
# 1416871     NaN         NaN  NaN   Cloud 9 TAP  Cloud 9 DMI Subscribers
# 1416872     NaN         NaN  NaN   Cloud 9 TAP  Cloud 9 DMI Subscribers
#
#          STATUS              START_DATE SUBSCRIBER_ID
# 1416870  Active 2016-11-10 20:31:56.537        195675
# 1416871  Active 2016-11-10 20:32:18.673        195677
# 1416872  Active 2016-11-10 20:32:28.483        195678

# %%
df_dmi_n.groupby([df_dmi_n.RESELLER_NAME, df_dmi_n.ACCOUNT_NAME], as_index=False)['IMSI'].count()
# Out:
#                     RESELLER_NAME                            ACCOUNT_NAME  \
# 0                     Cloud 9 TAP                 Cloud 9 DMI Subscribers
# 1                        HMG Int                   HMG Int simcards tests
# 2      KnowRoaming IMSI-RANGE TAP                                 test_kr
# 3                       Maxcom RT                          Celmax-Soriana
# 4                       Maxcom RT                         Maxcom Test Sim
# 5                        Mobileye                  Mobileye test simcards
# 6                  Mondicon Relay  Mondicon  IMSI Range Real Time (Relay)
# 7                  Mondicon Relay           Mondicon IMSI Range SIM Cards
# 8          MultiByte  RB Simcards                MultiByte Test Sim cards
# 9                  Netmore DMI RT                 netmore DMI Subscribers
# 10                  Nextel DMI RT                                  Nextel
# 11                  Nextel DMI RT                            Test account
# 12            Porto Seguro DMI RT                    Porto Seguro Conecta
# 13                       RUSEC RT                          RUSEC Test SIM
# 14          Roamability Invertory          Roamability simcards Inventory
# 15            Roamability Test RT                  RB Test hosted GGSN KR
# 16            Roamability Test RT                Roamability - SMPP TEST
# 17            Roamability Test RT              Roamability Test Sim-cards
# 18            Roamability Test RT                       Sure sample cards
# 19            Roamability Test RT                             soapApiTest
# 20                  STI - Telinta                                G1S_SWTL
# 21              Telzar 019 DMI RT                  019 Production Account
# 22              Telzar 019 DMI RT                        019 Test Account
# 23                   TinkLabs  RT              Tinklabs  Partner simcards
# 24                   TinkLabs  RT                       Tinklabs Simcards
# 25  Yuval Gaoni Partner SIM CARDS                 Yuval PArtner sim-cards
# 26                  uCloudLink RT               uCloudLink Soft sim-cards
#
#     IMSI
# 0     10
# 1      1
# 2      1
# 3      2
# 4      4
# 5     10
# 6    134
# 7   1817
# 8      1
# 9    448
# 10   123
# 11     3
# 12    25
# 13     2
# 14     1
# 15     1
# 16     1
# 17     4
# 18     1
# 19     1
# 20     2
# 21   139
# 22     3
# 23   240
# 24     1
# 25    29
# 26     1

# %%
df_dmi_n[(df_dmi_n.ACCOUNT_NAME == 'Mondicon IMSI Range SIM Cards')].head(3)
# Out:
#         MVNO_NAME                  IMSI MSISDN                S_IMSI PROF_ID  \
# 1416363       NaN       425010777631162    NaN       425010777631162     NaN
# 1416364       NaN  89972011215043609895    NaN  89972011215043609895     NaN
# 1416365       NaN       425010777293136    NaN       425010777293136     NaN
#
#         SP_NAME SIM_APP_VER FLAG   RESELLER_NAME  \
# 1416363     NaN         NaN  NaN  Mondicon Relay
# 1416364     NaN         NaN  NaN  Mondicon Relay
# 1416365     NaN         NaN  NaN  Mondicon Relay
#
#                           ACCOUNT_NAME  STATUS              START_DATE  \
# 1416363  Mondicon IMSI Range SIM Cards  Active 2017-02-08 15:35:38.317
# 1416364  Mondicon IMSI Range SIM Cards  Active 2017-02-08 15:42:16.977
# 1416365  Mondicon IMSI Range SIM Cards  Active 2017-02-08 15:45:04.160
#
#         SUBSCRIBER_ID
# 1416363        206434
# 1416364        206438
# 1416365        206441

# %%
print_raw_data('425010777631162')
# Out:
# Данные DMI:
# Empty DataFrame
# Columns: [MVNO_NAME, IMSI, MSISDN, S_IMSI, PROF_ID, SP_NAME, SIM_APP_VER, FLAG, SPONSOR]
# Index: []
# Данные OCS:
#        RESELLER_NAME                   ACCOUNT_NAME             IMSI  \
# 2931  Mondicon Relay  Mondicon IMSI Range SIM Cards  425010777631162
#
#                S_IMSI  STATUS              START_DATE SUBSCRIBER_ID
# 2931  425010777631162  Active 2017-02-08 15:35:38.317        206434
# Объединенные данные DMI и OCS:
#         MVNO_NAME             IMSI MSISDN           S_IMSI PROF_ID SP_NAME  \
# 1416363       NaN  425010777631162    NaN  425010777631162     NaN     NaN
#
#         SIM_APP_VER FLAG   RESELLER_NAME                   ACCOUNT_NAME  \
# 1416363         NaN  NaN  Mondicon Relay  Mondicon IMSI Range SIM Cards
#
#          STATUS              START_DATE SUBSCRIBER_ID
# 1416363  Active 2017-02-08 15:35:38.317        206434

# %%
# Выгрузить в файл

# Summary
df_dmi_n.groupby([df_dmi_n.RESELLER_NAME, df_dmi_n.ACCOUNT_NAME],
                 as_index=False)['IMSI'].count().to_csv(join(downloads, ''))

# %% [markdown]
# ### Оценка корректности профайлов в DMI

# %%
df_dmi['SPONSOR'] = np.nan
df_dmi.loc[df_dmi.S_IMSI.str.startswith('42501', na=False), ['SPONSOR']] = 'S1'
df_dmi.loc[df_dmi.S_IMSI.str.startswith('26006', na=False), ['SPONSOR']] = 'S2'

# %%
df_prof_book.head(3)
# Out:
#    MVNO_NAME           SP_NAME SPONSOR   PROFILE
# 0    Cellact       P4_Combined      S2  Combined
# 1    Cellact  Partner_Combined      S1  Combined
# 2  Citictell       P4_Combined      S2  Combined

# %%
df_sponsor_dmi = df_dmi.groupby(['MVNO_NAME', 'SP_NAME', 'SPONSOR'],
                                as_index=False)['IMSI'].count().sort_values(by=['MVNO_NAME', 'SP_NAME'])
df_sponsor_dmi.head(3)
# Out:
#    MVNO_NAME           SP_NAME SPONSOR  IMSI
# 0    Cellact       P4_Combined      S2     5
# 1    Cellact  Partner_Combined      S1     5
# 2  Citictell       P4_Combined      S2     3

# %%
df_temp = pd.merge(df_sponsor_dmi, df_prof_book, how='left', on=['MVNO_NAME', 'SP_NAME', 'SPONSOR'])
df_temp[df_temp.PROFILE.isnull()]
# Out:
#            MVNO_NAME           SP_NAME SPONSOR  IMSI PROFILE
# 6   Dialoq_Partner_S  Partner_Dialoq_A      S1    12     NaN
# 7                 MB       P4_Combined      S2     2     NaN
# 8                 MB  Partner_Combined      S1     2     NaN
# 13          Mondicon       P4_Mon-Germ      S2    25     NaN
# 20          Mondicon     Partner_BLOCK      S1  1118     NaN
# 27         MultiByte       P4_Combined      S2     1     NaN
# 28         MultiByte  Partner_Combined      S1     1     NaN
# 29            Nextel            P4_All      S2     2     NaN
# 35   RB_fastint_test  Partner_Combined      S1     1     NaN
# 38  RedT_Partner_Sof            P4_All      S2    15     NaN
# 40           Rewicom            P4_All      S2     1     NaN
# 43       Roamability                P4      S2     1     NaN
# 44       Roamability           P4_2018      S2     6     NaN
# 47       Roamability    P4_KeepGo_Test      S2     4     NaN
# 48       Roamability        P4_RB_test      S2     3     NaN
# 50       Roamability            P4_lot      S2     4     NaN
# 51       Roamability  PTNR_KeepGo_Test      S1     4     NaN
# 52       Roamability      Partner_2018      S1    10     NaN
# 55       Roamability  Partner_WeConnec      S1    30     NaN
# 57       Roamability  Partner_mobileye      S1     1     NaN
# 58       Roamability    Partner_uCloud      S1    50     NaN
# 59               STI       P4_STI_Comb      S1     1     NaN
# 70            Telzar       P4_Combined      S2     2     NaN
# 71            Telzar        P4_RB_test      S2     1     NaN
# 74            Telzar  Partner_Combined      S1     2     NaN
# 76       Telzar_Soft         P4_telzar      S2    24     NaN
# 78     Telzar_newHSS        P4_RB_test      S2     2     NaN
# 79     Telzar_newHSS         P4_telzar      S2     1     NaN
# 80     Telzar_newHSS    Partner_telzar      S1     3     NaN
# 83      WMB_Combined       P4_Combined      S2    13     NaN
# 85      WMB_Combined  Partner_Combined      S1    20     NaN
# 87             X2One       P4_Combined      S2     1     NaN
# 88             X2One  Partner_Combined      S1     1     NaN
# 89               lot       P4_Combined      S2     1     NaN
# 90               lot            P4_lot      S2     1     NaN
# 91               lot  Partner_Combined      S1     2     NaN

# %%
# Выгрузить в файл

df_temp.loc[df_temp.PROFILE.isnull(),
            ['MVNO_NAME', 'SP_NAME', 'SPONSOR', 'IMSI']].to_csv(join(downloads, 'DmiIncorrectProfilesSummary.csv'), index=False)

pd.merge(df_dmi,
         df_temp.loc[df_temp.PROFILE.isnull(), ['MVNO_NAME', 'SP_NAME', 'SPONSOR']], how='inner',
         on=['MVNO_NAME', 'SP_NAME', 'SPONSOR']).to_csv(join(downloads, 'DmiIncorrectProfiles.csv'), index=False)

# %% [markdown]
# ### Поиск дублированных в OCS записей

# %%
s_imsi_dublicated = df_ocs.loc[df_ocs.STATUS == 'Active', ['IMSI', 'S_IMSI']].groupby(['IMSI', 'S_IMSI']).size()
s_imsi_dublicated[s_imsi_dublicated.values > 1]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ### Testing
