# %% [markdown]
# ## Сравнение тарифов двух и более спонсоров из файлов
# - Делается сравнение покрытия по странам
# - Делается сравнения покрытия по LTE
# - Делается сравнение тарифов по странам с подкраской минимального тарифа (с подкраской LTE)
# - Выгружается файл сравнения
# - Выполняется проверка пропавших и появившихся операторов и стран для Combined Allowed List
#
# По результатам выполнения данной процедуры можно принимать решение об изменении Allowed List.
# Для загрузки изменений Allowed List использовать методику c:\W_DATA_ROAM\МЕТОДИКИ\_NOC_M_NEW_CONNECTION\020_DMI_ALLOWED_LIST+STS\

# %% [markdown]
# ### Подготовка данных

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import pyodbc
import datetime as dt
from os.path import join
import roamability as rb

# %%
# Из базы данных OCS выгружаем TADIG

# Connect to OCSDBREP1 (BSS)

cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER=172.18.11.82;DATABASE=10028;UID=BSS;PWD=iKQVm40AZAmyRaw72LeY')

# Получение данных TADIG

sql_srt=\
'''
SELECT DISTINCT c.COUNTRY_NAME AS COUNTRY,n.NETWORK_NAME AS NETWORK,t.TADIG_CODE AS TADIG,t.NETWORK_ID FROM RDB_TADIG_CODES t
LEFT JOIN RDB_NETWORKS n ON t.network_id = n.network_id
LEFT JOIN RDB_COUNTRIES c ON n.country_id = c.country_id
'''
df_tadig = pd.read_sql_query(sql_srt, cnxn)

cnxn.close()

df_tadig.head(3)
# Out:
#        COUNTRY                                 NETWORK  TADIG  NETWORK_ID
# 0  Afghanistan  Afghan Wireless Communication Company   AFGAW         4.0
# 1  Afghanistan                              Areeba/MTN  AFGAR         5.0
# 2  Afghanistan                                Etisalat  AFG55         6.0

# %%
# Описываем класс данных Спонсора

class SponsorClass:
    
    def __init__(self, name, sponsor_id, ocs_roaming_plan_id, roamdb_tarifflistid,
                 reload_tariff_from_db = False, downloads = None, tariff_file_name = None):
        self.name = name
        self.sponsor_id = sponsor_id
        self.ocs_roaming_plan_id = ocs_roaming_plan_id
        self.roamdb_tarifflistid = roamdb_tarifflistid
        self.df_ocs_cost = DataFrame()
        self.df_roamdb = DataFrame()
        
        self.downloads = downloads
        self.tariff_file_name = tariff_file_name
        
        if reload_tariff_from_db:
            self.upload_data_from_ocs()
            self.upload_data_from_roamdb()
            df_temp = pd.merge(self.df_ocs_cost, self.df_roamdb, how='left', on='TADIG')
            self.df_tariff = pd.merge(df_temp, df_tadig, how='left', on='TADIG')
        else:
            self.prepare_pp()
        
    def ocs_tariff_gen(self):
        '''Функция для подготовки SQL запроса для выгрузки тарифов из OCS'''
        sql_srt=\
        '''
        SELECT t.tadig_code AS TADIG
        ,MO_CALL_RATE MOC,MT_CALL_RATE MTC,MO_SMS_RATE SMS,DATA_RATE DATA
        FROM ROAMING_PLAN_RULES r
        LEFT JOIN RDB_TADIG_CODES t
        ON r.network_id=t.network_id
        LEFT JOIN ROAMING_PLANS p
        ON r.roaming_plan_id=p.roaming_plan_id
        WHERE r.roaming_plan_id IN ({0})
        AND r.SPONSOR_ID = {1}
        AND p.deleted IS NULL
        AND r.end_date IS NULL
        AND r.is_discounted = 1
        '''.format(self.ocs_roaming_plan_id, self.sponsor_id)
        return sql_srt
    
    def roamdb_gen(self):
        '''Функция для подготовки SQL запроса для выгрузки тарифов из RoamDB'''
        sql_srt=\
        '''
        SELECT t.outgoingvoiceincrement_SEC AS Voice_Increment_SEC
        ,t.dataincrement_KB AS Data_Increment_KB
        ,IIF(t.support4G = 1, 'Yes', 'No') AS LTE,tc.value AS TADIG FROM Tariffs t
        INNER JOIN TadigCodes tc
        ON t.OperatorID = tc.OperatorID
        WHERE t.tarifflistid = {0}
        '''.format(self.roamdb_tarifflistid)
        return sql_srt
    
    def upload_data_from_ocs(self):
        cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER=172.18.11.82;DATABASE=10028;UID=BSS;PWD=iKQVm40AZAmyRaw72LeY')
        sql_srt = self.ocs_tariff_gen()
        self.df_ocs_cost = pd.read_sql_query(sql_srt, cnxn)
        cnxn.close()
        
    def upload_data_from_roamdb(self):
        cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER=172.19.11.59;DATABASE=RoamDB;UID=roamdb;PWD=roamdbpasswd')
        sql_srt = self.roamdb_gen()
        self.df_roamdb = pd.read_sql_query(sql_srt, cnxn)
        cnxn.close()
        
    def prepare_pp(self):
        '''Функция для подготовки DF из файла.
        Объединение с TADIG, COUNTRY и NETWORK_ID из OCS.
        Фильтрация по максимальному тарифу передачи данных.'''
        df_temp = pd.read_csv(join(self.downloads, self.tariff_file_name))
        df_temp = df_temp[df_temp['DATA'] <= discount_data_price_threshold]
        df_temp = pd.merge(df_temp, df_tadig, how='left', on='TADIG')
        self.df_tariff = df_temp

# %%
#######################################################################################
# Define variables here
#######################################################################################

dmi_allowed_list = 'DMI.dmi_allowed_list_export_Fri_Dec_20_2019.csv'
combined_dict = {'Partner_Combined':'S1', 'P4_Combined':'S2', 'MB_Combined':'S4'}
discount_data_price_threshold = 0.7 # USD
downloads = r'c:\Users\balob\Documents\GITLAB\RB_BD\DATA'

reload_tariff_from_db = False

# Output file names
file_compare_by_country_coverage = 'CompareByCountryCoverage.csv'
file_compare_by_lte_coverage = 'CompareByLteCoverage.csv'
file_compare_tariffs = 'CompareTariffs.csv'
file_country_min_tariffs = 'CountryMinTariff.xlsx'
file_country_min_tariffs_lte = 'CountryMinTariffLte.xlsx'
file_operator_min_tariffs_lte = 'OperatorMinTariffLte.xlsx'

# Files with the tariffs should contain the following fields:
# TADIG,MOC,MTC,SMS,DATA,Voice_Increment_SEC,Data_Increment_KB,LTE

# name, sponsor_id, ocs_roaming_plan_id, roamdb_tarifflistid, reload_tariff_from_db, downloads, tariff_file_name
s1_sponsor = SponsorClass('S1', 1, 267, 35, tariff_file_name = 'S1_20200101.csv',
                          reload_tariff_from_db = reload_tariff_from_db, downloads = downloads)
s2_sponsor = SponsorClass('S2', 2, 268, 34, tariff_file_name = 'S2_20200101.csv',
                          reload_tariff_from_db = reload_tariff_from_db, downloads = downloads)
s4_sponsor = SponsorClass('S4', 4, 329, 36, tariff_file_name = 'S4_20200101.csv',
                          reload_tariff_from_db = reload_tariff_from_db, downloads = downloads)
s5_sponsor = SponsorClass('S5', 5, 343, 32, tariff_file_name = 'S5_20200101.csv',
                          reload_tariff_from_db = reload_tariff_from_db, downloads = downloads)
s8_sponsor = SponsorClass('S8', 8, 372, 37, tariff_file_name = 'S8_20200101.csv',
                          reload_tariff_from_db = reload_tariff_from_db, downloads = downloads)

# sponsors = [s1_sponsor, s2_sponsor, s4_sponsor, s5_sponsor, s8_sponsor]
sponsors = [s1_sponsor, s2_sponsor, s4_sponsor, s5_sponsor, s8_sponsor]

#######################################################################################

#######################################################################################

# %%
for sponsor in sponsors:
    print(f'\nTariffs of {sponsor.name}:')
    display(sponsor.df_tariff.head(3))
# Out:
# Tariffs of S1:
#    TADIG     MOC  MTC     SMS    DATA  Voice_Increment_SEC  Data_Increment_KB  \
# 0  ALBAM  0.2600  0.0  0.0300  0.0090                  1.0                1.0
# 1  ALBVF  0.0300  0.0  0.0060  0.0024                  1.0                1.0
# 2  AIACW  0.1606  0.0  0.0128  0.0257                 60.0                1.0
#
#    LTE   COUNTRY               NETWORK  NETWORK_ID
# 0   No   Albania  TELEKOM ALBANIA SH A         9.0
# 1  Yes   Albania              Vodafone        12.0
# 2   No  Anguilla    Cable and Wireless        20.0
# Tariffs of S2:
#    TADIG      MOC  MTC     SMS     DATA  Voice_Increment_SEC  \
# 0  ALBAM  0.51635  0.0  0.0598  0.04600                  1.0
# 1  ALBEM  0.44850  0.0  0.0460  0.04485                 60.0
# 2  AUSOP  0.06325  0.0  0.0092  0.00920                 60.0
#
#    Data_Increment_KB  LTE    COUNTRY               NETWORK  NETWORK_ID
# 0                1.0  Yes    Albania  TELEKOM ALBANIA SH A         9.0
# 1                1.0  Yes    Albania          Eagle Mobile        10.0
# 2                1.0  Yes  Australia         Singtel Optus        45.0
# Tariffs of S4:
#    TADIG   MOC   MTC   SMS      DATA  Voice_Increment_SEC  Data_Increment_KB  \
# 0  AUSVF  0.26  0.26  0.26  0.005000                 60.0                1.0
# 1  CANRW  0.26  0.26  0.26  0.005000                 60.0                1.0
# 2  CHNCU  0.26  0.26  0.26  0.006301                 60.0                1.0
#
#    LTE    COUNTRY                                   NETWORK  NETWORK_ID
# 0  Yes  Australia  Vodafone Hutchison Australia Pty Limited        49.0
# 1  Yes     Canada         Rogers Communications Canada Inc        164.0
# 2  Yes      China                              China Unicom       199.0
# Tariffs of S5:
#    TADIG     MOC     MTC       SMS      DATA  Voice_Increment_SEC  \
# 0  ALBVF  0.1610  0.0000  0.008625  0.008625                 60.0
# 1  ARGCM  0.4025  0.0345  0.011500  0.009200                 60.0
# 2  ARGTM  0.6900  0.1150  0.115000  0.115000                  NaN
#
#    Data_Increment_KB  LTE    COUNTRY              NETWORK  NETWORK_ID
# 0                1.0   No    Albania             Vodafone        12.0
# 1                1.0  Yes  Argentina   AMX Argentina S A         25.0
# 2                NaN  NaN  Argentina  Movistar/Telefonica        27.0
# Tariffs of S8:
#    TADIG     MOC  MTC     SMS    DATA Voice_Increment_SEC  Data_Increment_KB  \
# 0  AFGAR  1.0164  0.0  0.1236  0.1044                None                1.0
# 1  AFG55  0.7956  0.0  0.2880  0.2976                None                1.0
# 2  ALBAM  0.6096  0.0  0.1932  0.0180                None                1.0
#
#   LTE      COUNTRY               NETWORK  NETWORK_ID
# 0  No  Afghanistan            Areeba/MTN         5.0
# 1  No  Afghanistan              Etisalat         6.0
# 2  No      Albania  TELEKOM ALBANIA SH A         9.0

# %%
# Загрузить Combined Allowed list

df_al=pd.read_csv(join(downloads, dmi_allowed_list), usecols=['Sponsor','PLMN code'])
df_al.rename({'PLMN code':'TADIG_AL','Sponsor':'SPONSOR'}, inplace=True, axis=1)
df_al = df_al[df_al.SPONSOR.isin(list(combined_dict))]
df_al = df_al.replace(combined_dict)
df_al = pd.merge(df_al, df_tadig[['COUNTRY','TADIG','NETWORK_ID']], how='left', left_on='TADIG_AL', right_on='TADIG')
df_al.drop('TADIG', inplace=True,axis=1)

# Проверить дублирования стран в Combined Allowed List

s_temp = df_al.groupby('COUNTRY')['SPONSOR'].nunique()
if s_temp[s_temp > 1].count():
    print('Duplicates per Country in the Combined Allowed List:')
    display(s_temp[s_temp > 1])
else:
    print('No duplicates per Country found in the Combined Allowed List.')

df_al.head(3)
# Out:
# No duplicates per Country found in the Combined Allowed List.
#   SPONSOR TADIG_AL     COUNTRY  NETWORK_ID
# 0      S2    HRVT2     Croatia       225.0
# 1      S1    GTMTG   Guatemala       366.0
# 2      S2    MNEMT  Montenegro       622.0

# %%
# Получаем данные по Usage из BSS

start_date = '20191101'
end_date = '20191130'

sql_srt="""
SELECT RepDate,SponsorPrefix,VisitedNetworkId AS NETWORK_ID,UsageType,SUM(Cost) Cost, SUM(Revenue) Revenue, SUM(Volume) Volume FROM
(
SELECT
DATE_FORMAT(Day, "%Y-%m") AS RepDate,SponsorPrefix,VisitedNetworkId,Customer,Cost,Revenue,Volume
,'DATA' AS UsageType
FROM aggreg.GPRS_AGR
WHERE `Day` BETWEEN {start_date} AND {end_date}
UNION ALL
SELECT
DATE_FORMAT(Day, "%Y-%m") AS RepDate,SponsorPrefix,VisitedNetworkId,Customer,Cost,Revenue,NbEvent AS Volume
,CASE WHEN Sms = 0 THEN 'MOC' WHEN Sms = 1 THEN 'MOSMS' END AS UsageType
FROM aggreg.MOC_AGR
WHERE `Day` BETWEEN {start_date} AND {end_date}
UNION ALL
SELECT
DATE_FORMAT(Day, "%Y-%m") AS RepDate,SponsorPrefix,VisitedNetworkId,Customer,Cost,Revenue,NbEvent AS Volume
,CASE WHEN Sms = 0 THEN 'MTC' WHEN Sms = 1 THEN 'MTSMS' END AS UsageType
FROM aggreg.MTC_AGR
WHERE `Day` BETWEEN {start_date} AND {end_date}
) t GROUP BY RepDate,SponsorPrefix,VisitedNetworkId,UsageType
""".format(start_date=start_date, end_date=end_date)

with rb.MySqlConnect('172.18.11.40', 'BSS', 'noc', 'WcQUzkXiXwoxnFfGnRxb') as cnxn:
    df_bss_source = pd.read_sql_query(sql_srt, cnxn)

# sql_srt='SELECT network_id AS VisitedNetworkId, MAX(tadig_code) AS Tadig FROM RDB_TADIG_CODES GROUP BY network_id;'
# with rb.MssqlConnect('172.18.11.82', '10028', 'BSS', 'iKQVm40AZAmyRaw72LeY') as cnxn:
#     df_tadig = pd.read_sql_query(sql_srt, cnxn, coerce_float=False)

df_bss_source.SponsorPrefix.replace({42501:1, 26006:2, 45403:4, 51503:5}, inplace=True)
df_bss_source = df_bss_source.pivot_table(values='Volume',index=['RepDate','SponsorPrefix','NETWORK_ID']
                   ,columns='UsageType', aggfunc=np.sum).reset_index()

df_bss_processed = pd.merge(df_bss_source, df_tadig[['COUNTRY','NETWORK_ID']].drop_duplicates(), how='left', on='NETWORK_ID')
df_bss_processed = df_bss_processed[['RepDate','SponsorPrefix','COUNTRY','NETWORK_ID','MOC','MTC','MOSMS','MTSMS','DATA']]
df_bss_processed.DATA = df_bss_processed.DATA/1024/1024/1024
df_bss_processed.head(3)
# Out:
#    RepDate  SponsorPrefix              COUNTRY  NETWORK_ID    MOC    MTC  \
# 0  2019-11              1              Albania          12  523.0  165.0
# 1  2019-11              1             Anguilla          20    NaN    NaN
# 2  2019-11              1  Antigua and Barbuda          23    NaN    NaN
#
#    MOSMS  MTSMS       DATA
# 0   12.0  108.0  17.660431
# 1    NaN    NaN   0.003150
# 2    NaN    NaN   0.163789

# %% [markdown]
# ### Cравнение покрытия по странам

# %%
df = DataFrame({'COUNTRY':[]})
for sponsor in sponsors:
    df_temp = sponsor.df_tariff.groupby('COUNTRY', as_index=False)['DATA'].min().rename({'DATA':f'DATA_{sponsor.name}'}, axis=1)
    df = pd.merge(df, df_temp, how='outer', on='COUNTRY')

df = df[df.isnull().any(axis=1)]
df.to_csv(join(downloads, file_compare_by_country_coverage), index=False)
df.head()
# Out:
#                COUNTRY  DATA_S1  DATA_S2  DATA_S4   DATA_S5  DATA_S8
# 0              Albania   0.0024  0.04485      NaN  0.008625    0.018
# 1             Anguilla   0.0257      NaN      NaN       NaN    0.126
# 2  Antigua and Barbuda   0.0240      NaN      NaN       NaN    0.126
# 3            Argentina   0.0140      NaN      NaN  0.009200    0.054
# 4              Armenia   0.0040      NaN      NaN       NaN    0.018

# %% [markdown]
# ### Сравнение покрытия по LTE

# %%
df = DataFrame({'COUNTRY':[]})
for sponsor in sponsors:
    df_temp = sponsor.df_tariff.groupby('COUNTRY', as_index=False)['LTE'].max().rename({'LTE':f'LTE_{sponsor.name}'}, axis=1)
    df = pd.merge(df, df_temp, how='outer', on='COUNTRY')

df = df[(df == 'Yes').any(axis=1) & (df == 'No').any(axis=1)]
df.to_csv(join(downloads, file_compare_by_lte_coverage), index=False)
df.head()
# Out:
#                COUNTRY LTE_S1 LTE_S2 LTE_S4 LTE_S5 LTE_S8
# 0              Albania    Yes    Yes    NaN     No    Yes
# 1             Anguilla     No    NaN    NaN    NaN    Yes
# 2  Antigua and Barbuda     No    NaN    NaN    NaN    Yes
# 4              Armenia     No    NaN    NaN    NaN    Yes
# 7           Azerbaijan    Yes     No    NaN     No     No

# %% [markdown]
# ### Сравнение тарифов по странам

# %%
df = DataFrame({'COUNTRY':[]})
for sponsor in sponsors:
    df_temp = sponsor.df_tariff.groupby('COUNTRY', as_index=False)['DATA'].min().rename({'DATA':f'DATA_{sponsor.name}'}, axis=1)
    df = pd.merge(df, df_temp, how='outer', on='COUNTRY')
    
df = pd.merge(df, df_bss_processed.groupby('COUNTRY', as_index=False)['DATA'].sum(), how='left', on='COUNTRY')

df = pd.merge(df, df_al.groupby('COUNTRY', as_index=False)['SPONSOR'].first(), how='outer', on='COUNTRY')

df_country_compare = df.sort_values(by='DATA', ascending=False)

def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.min()
    return ['background-color: #81EF21' if v else '' for v in is_max]

data_tariff_name_list = [f'DATA_{sponsor.name}' for sponsor in sponsors]

df_country_compare.round(5).style.apply(highlight_max, subset=data_tariff_name_list, axis=1)\
.to_excel(join(downloads, file_country_min_tariffs), 'Sheet1', index=False)

display(df_country_compare.head(20).round(5).style.apply(highlight_max, subset=data_tariff_name_list, axis=1).hide_index())
# Out:
# <style  type="text/css" >
#     #T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow0_col1 {
#             background-color:  #81EF21;
#         }    #T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow1_col2 {
#             background-color:  #81EF21;
#         }    #T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow2_col2 {
#             background-color:  #81EF21;
#         }    #T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow3_col2 {
#             background-color:  #81EF21;
#         }    #T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow4_col1 {
#             background-color:  #81EF21;
#         }    #T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow5_col4 {
#             background-color:  #81EF21;
#         }    #T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow6_col1 {
#             background-color:  #81EF21;
#         }    #T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow7_col4 {
#             background-color:  #81EF21;
#         }    #T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow8_col2 {
#             background-color:  #81EF21;
#         }    #T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow9_col2 {
#             background-color:  #81EF21;
#         }    #T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow10_col1 {
#             background-color:  #81EF21;
#         }    #T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow11_col1 {
#             background-color:  #81EF21;
#         }    #T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow12_col1 {
#             background-color:  #81EF21;
#         }    #T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow13_col1 {
#             background-color:  #81EF21;
#         }    #T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow13_col3 {
#             background-color:  #81EF21;
#         }    #T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow14_col1 {
#             background-color:  #81EF21;
#         }    #T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow15_col1 {
#             background-color:  #81EF21;
#         }    #T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow16_col2 {
#             background-color:  #81EF21;
#         }    #T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow17_col3 {
#             background-color:  #81EF21;
#         }    #T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow18_col3 {
#             background-color:  #81EF21;
#         }    #T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow19_col2 {
#             background-color:  #81EF21;
#         }</style><table id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9c" ><thead>    <tr>        <th class="col_heading level0 col0" >COUNTRY</th>        <th class="col_heading level0 col1" >DATA_S1</th>        <th class="col_heading level0 col2" >DATA_S2</th>        <th class="col_heading level0 col3" >DATA_S4</th>        <th class="col_heading level0 col4" >DATA_S5</th>        <th class="col_heading level0 col5" >DATA_S8</th>        <th class="col_heading level0 col6" >DATA</th>        <th class="col_heading level0 col7" >SPONSOR</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow0_col0" class="data row0 col0" >Italy</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow0_col1" class="data row0 col1" >0.0018</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow0_col2" class="data row0 col2" >0.00299</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow0_col3" class="data row0 col3" >nan</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow0_col4" class="data row0 col4" >0.00863</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow0_col5" class="data row0 col5" >0.0048</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow0_col6" class="data row0 col6" >2214.25</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow0_col7" class="data row0 col7" >S1</td>
#             </tr>
#             <tr>
#                                 <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow1_col0" class="data row1 col0" >United Kingdom</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow1_col1" class="data row1 col1" >0.0016</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow1_col2" class="data row1 col2" >0.00138</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow1_col3" class="data row1 col3" >nan</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow1_col4" class="data row1 col4" >0.00575</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow1_col5" class="data row1 col5" >0.0048</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow1_col6" class="data row1 col6" >2030.47</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow1_col7" class="data row1 col7" >S2</td>
#             </tr>
#             <tr>
#                                 <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow2_col0" class="data row2 col0" >Germany</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow2_col1" class="data row2 col1" >0.0024</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow2_col2" class="data row2 col2" >0.00121</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow2_col3" class="data row2 col3" >nan</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow2_col4" class="data row2 col4" >0.00863</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow2_col5" class="data row2 col5" >0.0072</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow2_col6" class="data row2 col6" >1532.89</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow2_col7" class="data row2 col7" >S2</td>
#             </tr>
#             <tr>
#                                 <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow3_col0" class="data row3 col0" >Spain</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow3_col1" class="data row3 col1" >0.0024</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow3_col2" class="data row3 col2" >0.00207</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow3_col3" class="data row3 col3" >nan</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow3_col4" class="data row3 col4" >0.00863</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow3_col5" class="data row3 col5" >0.012</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow3_col6" class="data row3 col6" >1497.3</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow3_col7" class="data row3 col7" >S2</td>
#             </tr>
#             <tr>
#                                 <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow4_col0" class="data row4 col0" >South Korea</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow4_col1" class="data row4 col1" >0.0016</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow4_col2" class="data row4 col2" >nan</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow4_col3" class="data row4 col3" >0.00315</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow4_col4" class="data row4 col4" >0.0023</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow4_col5" class="data row4 col5" >0.0324</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow4_col6" class="data row4 col6" >1158.86</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow4_col7" class="data row4 col7" >S1</td>
#             </tr>
#             <tr>
#                                 <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow5_col0" class="data row5 col0" >France</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow5_col1" class="data row5 col1" >0.0038</td>
#                         <td id="T_a5c2ccb4_27f1_11ea_a284_9cb6d0ea0f9crow5_col2

# %% [markdown]
# ### Новые страны для Combined Allowed List

# %%
# Новые страны для Combined Allowed List

df_country_compare[df_country_compare.SPONSOR.isna()]
# Out:
#                  COUNTRY  DATA_S1   DATA_S2  DATA_S4   DATA_S5  DATA_S8  DATA  \
# 11                 Benin    0.070       NaN      NaN       NaN      NaN   NaN
# 35              Ethiopia    0.250       NaN      NaN       NaN      NaN   NaN
# 46              Honduras    0.025       NaN      NaN  0.009200   0.0540   NaN
# 71             Mauritius    0.025       NaN      NaN  0.264500      NaN   NaN
# 88              Paraguay    0.025       NaN      NaN  0.009200   0.0540   NaN
# 93           Puerto Rico    0.025       NaN      NaN  0.009200   0.5328   NaN
# 127              Reunion      NaN  0.005405      NaN       NaN      NaN   NaN
# 130                 Guam      NaN       NaN   2.5805       NaN      NaN   NaN
# 134              Bahrain      NaN       NaN      NaN  0.011500   0.0180   NaN
# 135           Bangladesh      NaN       NaN      NaN  0.009545   0.0180   NaN
# 136    Brunei Darussalam      NaN       NaN      NaN  0.011500   0.0360   NaN
# 137             Cameroon      NaN       NaN      NaN  0.011500   0.1044   NaN
# 138                 Fiji      NaN       NaN      NaN  0.011500   0.0900   NaN
# 139            Greenland      NaN       NaN      NaN  0.011500   0.1044   NaN
# 140               Kuwait      NaN       NaN      NaN  0.002875   0.0096   NaN
# 141              Liberia      NaN       NaN      NaN  0.012880      NaN   NaN
# 142             Mongolia      NaN       NaN      NaN  0.005750   0.0204   NaN
# 144     Papua New Guinea      NaN       NaN      NaN  0.011500   0.0900   NaN
# 145                Qatar      NaN       NaN      NaN  0.002300   0.0900   NaN
# 146                Samoa      NaN       NaN      NaN  0.011500   0.0900   NaN
# 147                Tonga      NaN       NaN      NaN  0.011500   0.0900   NaN
# 148              Vanuatu      NaN       NaN      NaN  0.011500   0.0900   NaN
# 149          Afghanistan      NaN       NaN      NaN       NaN   0.1044   NaN
# 150              Algeria      NaN       NaN      NaN       NaN   0.0228   NaN
# 151                Aruba      NaN       NaN      NaN       NaN   0.0720   NaN
# 152               Belize      NaN       NaN      NaN       NaN   0.1776   NaN
# 153              Bolivia      NaN       NaN      NaN       NaN   0.0432   NaN
# 154         Burkina Faso      NaN       NaN      NaN       NaN   0.2676   NaN
# 155              Curacao      NaN       NaN      NaN       NaN   0.0720   NaN
# 156        Faroe Islands      NaN       NaN      NaN       NaN   0.0144   NaN
# 158        Guinea-Bissau      NaN       NaN      NaN       NaN   0.0996   NaN
# 159               Guyana      NaN       NaN      NaN       NaN   0.0720   NaN
# 160                 Iran      NaN       NaN      NaN       NaN   0.0180   NaN
# 161               Malawi      NaN       NaN      NaN       NaN   0.0900   NaN
# 162                 Mali      NaN       NaN      NaN       NaN   0.6096   NaN
# 163              Namibia      NaN       NaN      NaN       NaN   0.0228   NaN
# 164                 Oman      NaN       NaN      NaN       NaN   0.0888   NaN
# 165             Suriname      NaN       NaN      NaN       NaN   0.0720   NaN
# 166                 Togo      NaN       NaN      NaN       NaN   0.6096   NaN
# 167  Trinidad and Tobago      NaN       NaN      NaN       NaN   0.0720   NaN
# 169             Zimbabwe      NaN       NaN      NaN       NaN   0.5328   NaN
#
#     SPONSOR
# 11      NaN
# 35      NaN
# 46      NaN
# 71      NaN
# 88      NaN
# 93      NaN
# 127     NaN
# 130     NaN
# 134     NaN
# 135     NaN
# 136     NaN
# 137     NaN
# 138     NaN
# 139     NaN
# 140     NaN
# 141     NaN
# 142     NaN
# 144     NaN
# 145     NaN
# 146     NaN
# 147     NaN
# 148     NaN
# 149     NaN
# 150     NaN
# 151     NaN
# 152     NaN
# 153     NaN
# 154     NaN
# 155     NaN
# 156     NaN
# 158     NaN
# 159     NaN
# 160     NaN
# 161     NaN
# 162     NaN
# 163     NaN
# 164     NaN
# 165     NaN
# 166     NaN
# 167     NaN
# 169     NaN

# %% [markdown]
# ### Пропавшие и новые сети для Combined Allowed List

# %%
fields_list = ['COUNTRY','TADIG','TADIG_AL','DATA','SPONSOR']
df_new_mis_operatirs = DataFrame()

for sponsor in sponsors:
    df_sponsor = pd.merge(sponsor.df_tariff, df_al[df_al.SPONSOR == sponsor.name],
                       how='outer', on=['COUNTRY','NETWORK_ID'])[fields_list]
    s_sponsor = df_sponsor.loc[df_sponsor.SPONSOR == sponsor.name, 'COUNTRY'].unique()
    df_sponsor = df_sponsor.loc[df_sponsor.COUNTRY.isin(s_sponsor)]
    df_mis = df_sponsor.loc[df_sponsor.TADIG.isna()].copy()
    df_mis['COM'] = 'MIS'
    df_new = df_sponsor.loc[df_sponsor.SPONSOR.isna()].copy()
    df_new['COM'] = 'NEW'
    df_new['SPONSOR'] = sponsor.name
    df_new_mis_operatirs = df_new_mis_operatirs.append(df_mis).append(df_new)
    
df_new_mis_operatirs.sort_values(by='COUNTRY')
# Out:
#                COUNTRY  TADIG TADIG_AL      DATA SPONSOR  COM
# 0              Albania  ALBAM      NaN  0.009000      S1  NEW
# 270          Argentina  ARGVO      NaN  0.025000      S1  NEW
# 4            Argentina  ARGCM      NaN  0.025000      S1  NEW
# 269          Argentina  ARGTP      NaN  0.025000      S1  NEW
# 23              Brazil  BRACL      NaN  0.025000      S1  NEW
# 40               Chile  CHLSM      NaN  0.025000      S1  NEW
# 165            Denmark    NaN    DNKT2       NaN      S2  MIS
# 65             Ecuador  ECUPG      NaN  0.025000      S1  NEW
# 159              Egypt    NaN    EGYEM       NaN      S2  MIS
# 162            Finland    NaN    FINAM       NaN      S2  MIS
# 161            Finland    NaN    FIN2G       NaN      S2  MIS
# 157      French Guiana    NaN    FRAF4       NaN      S2  MIS
# 51             Germany  DEUE1      NaN  0.001207      S2  NEW
# 88           Guatemala  GTMSC      NaN  0.025000      S1  NEW
# 294  Hong Kong (China)    NaN    HKGM3       NaN      S1  MIS
# 293              India  INDIB      NaN  0.020000      S1  NEW
# 119          Indonesia  IDN89      NaN  0.015000      S1  NEW
# 264            Ireland  IRLH3      NaN  0.001600      S1  NEW
# 163         Kazakhstan    NaN    KAZKT       NaN      S2  MIS
# 155           Malaysia    NaN    MYSMI       NaN      S2  MIS
# 166           Malaysia    NaN    MYSMT       NaN      S2  MIS
# 160             Mexico  MEXTL      NaN  0.025000      S1  NEW
# 154         Montenegro    NaN    MNEMT       NaN      S2  MIS
# 275        New Zealand  NZLNH      NaN  0.008000      S1  NEW
# 172          Nicaragua  NICEN      NaN  0.025000      S1  NEW
# 164             Norway    NaN    NORTM       NaN      S2  MIS
# 167           Pakistan    NaN    PAKTP       NaN      S2  MIS
# 181               Peru  PERTM      NaN  0.025000      S1  NEW
# 185        Philippines  PHLSR      NaN  0.006000      S1  NEW
# 160             Sweden    NaN    SWEEP       NaN      S2  MIS
# 220             Taiwan  TWNPC      NaN  0.020000      S1  NEW
# 219             Taiwan  TWNFE      NaN  0.005000      S1  NEW
# 221             Taiwan  TWNTM      NaN  0.020000      S1  NEW
# 24            Thailand  THACT      NaN  0.007560      S4  NEW
# 32            Thailand  THACA      NaN  0.007560      S4  NEW
# 31            Thailand  THACO      NaN  0.007560      S4  NEW
# 156            Tunisia    NaN    TUNTT       NaN      S2  MIS
# 125             Turkey  TURTC      NaN  0.004830      S2  NEW
# 126             Turkey  TURTK      NaN  0.004830      S2  NEW
# 158            Ukraine    NaN    UKRKS       NaN      S2  MIS
# 250            Uruguay  URYAM      NaN  0.025000      S1  NEW
# 253         Uzbekistan  UZB05      NaN  0.009000      S1  NEW
# 257            Vietnam  VNMVI      NaN  0.012000      S1  NEW
# 255            Vietnam  VNMMO      NaN  0.012000      S1  NEW

# %% [markdown]
# ### Выгрузка полного сравнительного листа в файл

# %%
# Выгрузка полного сравнительного листа в файл

df = DataFrame({'COUNTRY':[],'NETWORK_ID':[],'NETWORK':[],'TADIG':[]})
for sponsor in sponsors:
    df_temp = sponsor.df_tariff.rename({'MOC':f'MOC_{sponsor.name}'
                                        ,'MTC':f'MTC_{sponsor.name}'
                                        ,'SMS':f'SMS_{sponsor.name}'
                                        ,'DATA':f'DATA_{sponsor.name}'
                                        ,'LTE':f'LTE_{sponsor.name}'}
                                        , axis=1).drop(['Voice_Increment_SEC','Data_Increment_KB'], axis=1)
    df = pd.merge(df, df_temp, how='outer', on=['COUNTRY','NETWORK_ID','NETWORK','TADIG'])
    
cols = ['COUNTRY','NETWORK','TADIG']
for sponsor in sponsors:
    cols.extend([f'MOC_{sponsor.name}',f'MTC_{sponsor.name}',f'SMS_{sponsor.name}',f'DATA_{sponsor.name}',f'LTE_{sponsor.name}'])

df[cols].to_csv(join(downloads, file_compare_tariffs), index=False)
df[cols].head()
# Out:
#                COUNTRY               NETWORK  TADIG  MOC_S1  MTC_S1  SMS_S1  \
# 0              Albania  TELEKOM ALBANIA SH A  ALBAM  0.2600    0.00  0.0300
# 1              Albania              Vodafone  ALBVF  0.0300    0.00  0.0060
# 2             Anguilla    Cable and Wireless  AIACW  0.1606    0.00  0.0128
# 3  Antigua and Barbuda                 C & W  ATGCW  0.1500    0.00  0.0120
# 4            Argentina    AMX Argentina S A   ARGCM  0.2600    0.05  0.0400
#
#    DATA_S1 LTE_S1   MOC_S2  MTC_S2  ...  MOC_S5  MTC_S5    SMS_S5   DATA_S5  \
# 0   0.0090     No  0.51635     0.0  ...     NaN     NaN       NaN       NaN
# 1   0.0024    Yes      NaN     NaN  ...  0.1610  0.0000  0.008625  0.008625
# 2   0.0257     No      NaN     NaN  ...     NaN     NaN       NaN       NaN
# 3   0.0240     No      NaN     NaN  ...     NaN     NaN       NaN       NaN
# 4   0.0250    Yes      NaN     NaN  ...  0.4025  0.0345  0.011500  0.009200
#
#    LTE_S5  MOC_S8  MTC_S8  SMS_S8  DATA_S8  LTE_S8
# 0     NaN  0.6096  0.0000  0.1932   0.0180      No
# 1      No  0.2460  0.0000  0.1020   0.0204     Yes
# 2     NaN  0.3576  0.0000  0.2388   0.1260     Yes
# 3     NaN  0.3576  0.0000  0.2388   0.1260     Yes
# 4     Yes  0.8928  0.3576  0.4476   0.5328     Yes
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Сравнение тарифов по странам с подкраской LTE

# %%
# Подготовка DF для сравнения тарифов по странам с учетом LTE

df = DataFrame({'COUNTRY':[]})
for sponsor in sponsors:
    df_temp = sponsor.df_tariff.loc[:, ['COUNTRY', 'DATA', 'LTE']]
    df_temp = df_temp.loc[df_temp.groupby('COUNTRY')['DATA'].idxmin()]\
    .rename({'DATA':f'DATA_{sponsor.name}', 'LTE':f'LTE_{sponsor.name}'}, axis=1)
    df = pd.merge(df, df_temp.drop_duplicates(), how='outer', on='COUNTRY')

df = pd.merge(df, df_bss_processed.groupby('COUNTRY', as_index=False)['DATA'].sum(), how='left', on='COUNTRY')

df = pd.merge(df, df_al.groupby('COUNTRY', as_index=False)['SPONSOR'].first(), how='outer', on='COUNTRY')

df_country_compare = df.sort_values(by='DATA', ascending=False)

def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.min()
    return ['background-color: #e6ffe6' if v else '' for v in is_max]

def highlight_lte(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_lte = s == 'Yes'
    lte_list = ['color: #cc3300' if v else '' for v in is_lte]
    lte_list.append('')
    return lte_list[1:]

data_tariff_name_list = [f'DATA_{sponsor.name}' for sponsor in sponsors]

display(df_country_compare.head(15).round(5).style.apply(highlight_max, subset=data_tariff_name_list, axis=1)\
        .apply(highlight_lte, axis=1).hide_index())

df_country_compare.round(5).style.apply(highlight_max, subset=data_tariff_name_list, axis=1)\
        .apply(highlight_lte, axis=1).to_excel(join(downloads, file_country_min_tariffs_lte), 'Sheet1', index=False)
# Out:
# <style  type="text/css" >
#     #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow0_col1 {
#             background-color:  #e6ffe6;
#             : ;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow0_col7 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow1_col1 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow1_col3 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow1_col9 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow2_col1 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow2_col3 {
#             background-color:  #e6ffe6;
#             : ;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow2_col7 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow2_col9 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow3_col1 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow3_col3 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow3_col7 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow3_col9 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow4_col1 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow4_col5 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow4_col7 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow4_col9 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow5_col1 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow5_col3 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow5_col7 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow5_col9 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow6_col1 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow6_col3 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow6_col5 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow6_col7 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow6_col9 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow7_col1 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow7_col5 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow7_col7 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow7_col9 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow8_col1 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow8_col3 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow8_col7 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow8_col9 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow9_col3 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow9_col5 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow9_col7 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow9_col9 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow10_col1 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow10_col3 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow10_col5 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow10_col7 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow11_col1 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow11_col7 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow11_col9 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow12_col1 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow12_col3 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow12_col5 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow12_col7 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow12_col9 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow13_col1 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow13_col3 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow13_col5 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow13_col7 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow13_col9 {
#             : ;
#             color:  #cc3300;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow14_col1 {
#             background-color:  #e6ffe6;
#             : ;
#         }    #T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow14_col9 {
#             : ;
#             color:  #cc3300;
#         }</style><table id="T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9c" ><thead>    <tr>        <th class="col_heading level0 col0" >COUNTRY</th>        <th class="col_heading level0 col1" >DATA_S1</th>        <th class="col_heading level0 col2" >LTE_S1</th>        <th class="col_heading level0 col3" >DATA_S2</th>        <th class="col_heading level0 col4" >LTE_S2</th>        <th class="col_heading level0 col5" >DATA_S4</th>        <th class="col_heading level0 col6" >LTE_S4</th>        <th class="col_heading level0 col7" >DATA_S5</th>        <th class="col_heading level0 col8" >LTE_S5</th>        <th class="col_heading level0 col9" >DATA_S8</th>        <th class="col_heading level0 col10" >LTE_S8</th>        <th class="col_heading level0 col11" >DATA</th>        <th class="col_heading level0 col12" >SPONSOR</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow0_col0" class="data row0 col0" >Italy</td>
#                         <td id="T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow0_col1" class="data row0 col1" >0.0018</td>
#                         <td id="T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow0_col2" class="data row0 col2" >No</td>
#                         <td id="T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f9crow0_col3" class="data row0 col3" >0.00299</td>
#                         <td id="T_cede2bfa_27f1_11ea_895b_9cb6d0ea0f

# %% [markdown]
# ### Сравнение тарифов по операторам с подкраской LTE

# %%
# Сравнение тарифов по операторам с подкраской LTE

df = DataFrame({'COUNTRY':[], 'NETWORK':[],'NETWORK_ID':[]})
for sponsor in sponsors:
    df_temp = sponsor.df_tariff.groupby(['COUNTRY', 'NETWORK','NETWORK_ID'], as_index=False)[['DATA', 'LTE']].first()\
    .rename({'DATA':f'DATA_{sponsor.name}', 'LTE':f'LTE_{sponsor.name}'}, axis=1)
    df = pd.merge(df, df_temp.drop_duplicates(), how='outer', on=['COUNTRY','NETWORK','NETWORK_ID'])

df = pd.merge(df, df_bss_processed[['NETWORK_ID','DATA']], how='left', on='NETWORK_ID')
df = pd.merge(df, df_al.groupby('COUNTRY', as_index=False)['SPONSOR'].first(), how='outer', on='COUNTRY')

df_operator_compare = df.sort_values(by='DATA', ascending=False)
df_operator_compare.drop(['NETWORK_ID'], axis=1, inplace=True)

def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.min()
    return ['background-color: #e6ffe6' if v else '' for v in is_max]

def highlight_lte(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_lte = s == 'Yes'
    lte_list = ['color: #cc3300' if v else '' for v in is_lte]
    lte_list.append('')
    return lte_list[1:]

data_tariff_name_list = [f'DATA_{sponsor.name}' for sponsor in sponsors]

display(df_operator_compare.head(15).round(5).style.apply(highlight_max, subset=data_tariff_name_list, axis=1)\
        .apply(highlight_lte, axis=1).hide_index())

df_operator_compare.round(5).style.apply(highlight_max, subset=data_tariff_name_list, axis=1)\
        .apply(highlight_lte, axis=1).to_excel(join(downloads, file_operator_min_tariffs_lte), 'Sheet1', index=False)
# Out:
# <style  type="text/css" >
#     #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow0_col2 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow0_col4 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow1_col2 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow1_col6 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow1_col10 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow2_col2 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow2_col8 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow2_col10 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow3_col4 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow3_col10 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow4_col4 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow4_col6 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow4_col8 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow4_col10 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow5_col2 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow5_col4 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow5_col8 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow5_col10 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow6_col4 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow6_col10 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow7_col2 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow7_col4 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow7_col8 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow7_col10 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow8_col2 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow8_col8 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow8_col10 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow9_col2 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow9_col8 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow9_col10 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow10_col2 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow10_col4 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow10_col8 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow10_col10 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow11_col2 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow11_col4 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow11_col10 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow12_col2 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow12_col4 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow12_col8 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow12_col10 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow13_col2 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow13_col4 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow13_col8 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow13_col10 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow14_col2 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow14_col8 {
#             : ;
#             color:  #cc3300;
#         }    #T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow14_col10 {
#             : ;
#             color:  #cc3300;
#         }</style><table id="T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9c" ><thead>    <tr>        <th class="col_heading level0 col0" >COUNTRY</th>        <th class="col_heading level0 col1" >NETWORK</th>        <th class="col_heading level0 col2" >DATA_S1</th>        <th class="col_heading level0 col3" >LTE_S1</th>        <th class="col_heading level0 col4" >DATA_S2</th>        <th class="col_heading level0 col5" >LTE_S2</th>        <th class="col_heading level0 col6" >DATA_S4</th>        <th class="col_heading level0 col7" >LTE_S4</th>        <th class="col_heading level0 col8" >DATA_S5</th>        <th class="col_heading level0 col9" >LTE_S5</th>        <th class="col_heading level0 col10" >DATA_S8</th>        <th class="col_heading level0 col11" >LTE_S8</th>        <th class="col_heading level0 col12" >DATA</th>        <th class="col_heading level0 col13" >SPONSOR</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow0_col0" class="data row0 col0" >Italy</td>
#                         <td id="T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow0_col1" class="data row0 col1" >Wind Telecomunicazioni S p A</td>
#                         <td id="T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow0_col2" class="data row0 col2" >0.0018</td>
#                         <td id="T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow0_col3" class="data row0 col3" >Yes</td>
#                         <td id="T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow0_col4" class="data row0 col4" >0.0026</td>
#                         <td id="T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow0_col5" class="data row0 col5" >Yes</td>
#                         <td id="T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow0_col6" class="data row0 col6" >nan</td>
#                         <td id="T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow0_col7" class="data row0 col7" >nan</td>
#                         <td id="T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow0_col8" class="data row0 col8" >nan</td>
#                         <td id="T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow0_col9" class="data row0 col9" >nan</td>
#                         <td id="T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow0_col10" class="data row0 col10" >0.0048</td>
#                         <td id="T_922ddb50_23e4_11ea_ab22_9cb6d0ea0f9crow0_col11" class="data row0 col11" >No</td>

# %% [markdown]
# ### Подготовить файлы со всеми тарифами из файла для загрузки в OCS

# %%
# Подготовить файлы со всеми тарифами для загрузки в OCS

tariff_start_date = '2019-12-01 00:00:00'
charge_cost_increment = 2

def create_file_upload_to_ocs(sponsor_obj):
    df = sponsor_obj.df_tariff.copy()
    df['ROAMING_PLAN_RULE_ID'] = ''
    df['ROAMING_PLAN_ID']=''
    df['SPONSOR_ID'] = sponsor_obj.sponsor_id
    df['MT_SMS_RATE'] = 0
    df['CURRENCY_ID'] = 1 #1:USD, 2:EUR
    df['START_DATE'] = tariff_start_date
    df['END_DATE'] = 'NULL'
    df['is_discounted'] = 1
    return df

for sponsor in sponsors:
    df_temp = create_file_upload_to_ocs(sponsor)
    df_temp[['ROAMING_PLAN_RULE_ID',
            'ROAMING_PLAN_ID',
            'NETWORK_ID',
            'SPONSOR_ID',
            'MOC',
            'MTC',
            'SMS',
            'MT_SMS_RATE',
            'DATA',
            'CURRENCY_ID',
            'START_DATE',
            'END_DATE',
            'is_discounted']].drop_duplicates().to_csv(join(downloads, f'ocs_insert_{sponsor.name}_cost.csv'), index=False)
    
    df_temp[['MOC','MTC','SMS','DATA']] = df_temp[['MOC','MTC','SMS','DATA']] * charge_cost_increment
    
    df_temp[['ROAMING_PLAN_RULE_ID',
            'ROAMING_PLAN_ID',
            'NETWORK_ID',
            'SPONSOR_ID',
            'MOC',
            'MTC',
            'SMS',
            'MT_SMS_RATE',
            'DATA',
            'CURRENCY_ID',
            'START_DATE',
            'END_DATE',
            'is_discounted']].drop_duplicates().to_csv(join(downloads, f'ocs_insert_{sponsor.name}_charge.csv'), index=False)

# %% [markdown]
# ### Подготовить файлы со всеми тарифами из файла для загрузки в RoamDB

# %%
# Подготовить файлы со всеми тарифами для загрузки в RoamDB

columns_origin = ['TADIG',
  'MOC',
  'MTC',
  'SMS',
  'DATA',
  'Voice_Increment_SEC',
  'Data_Increment_KB',
  'IsDiscounted (Yes/No)',
  'LTE']

columns_roamdb = ['TADIG CODE',
 'Mobile Origination',
 'Mobile Termination',
 'SMS',
 'DATA',
 'Voice Increment',
 'Data Increment',
 'IsDiscounted (Yes/No)',
 'Support4G(Yes/No)',]

dict_roamdb_columns = dict(zip(columns_origin,columns_roamdb))

def create_file_upload_to_roamdb(sponsor_obj):
    df = sponsor_obj.df_tariff.copy()
    df['IsDiscounted (Yes/No)'] = 'Yes'
    return df.rename(dict_roamdb_columns, axis=1)

for sponsor in sponsors:
    df_temp = create_file_upload_to_roamdb(sponsor)
    df_temp[columns_roamdb].drop_duplicates().to_csv(join(downloads, f'roamdb_upload_{sponsor.name}.csv'), index=False)

# %% [markdown]
# ### Разработки

# %%
# Сравнение тарифов по операторам с подкраской LTE и с добавлением CAMEL

df = DataFrame({'COUNTRY':[], 'NETWORK':[],'NETWORK_ID':[]})

sponsors = [s5_sponsor, s8_sponsor]

for sponsor in sponsors:
    df_temp = sponsor.df_tariff.groupby(['COUNTRY', 'NETWORK','NETWORK_ID'], as_index=False)[['DATA', 'LTE', 'CAMEL']].first()\
    .rename({'DATA':f'DATA_{sponsor.name}', 'LTE':f'LTE_{sponsor.name}', 'CAMEL':f'CAMEL_{sponsor.name}'}, axis=1)
    df = pd.merge(df, df_temp.drop_duplicates(), how='outer', on=['COUNTRY','NETWORK','NETWORK_ID'])

df = pd.merge(df, df_bss_processed[['NETWORK_ID','DATA']], how='left', on='NETWORK_ID')
df = pd.merge(df, df_al.groupby('COUNTRY', as_index=False)['SPONSOR'].first(), how='outer', on='COUNTRY')

df_operator_compare = df.sort_values(by='DATA', ascending=False)
df_operator_compare.drop(['NETWORK_ID'], axis=1, inplace=True)

def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.min()
    return ['background-color: #e6ffe6' if v else '' for v in is_max]

def highlight_lte(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_lte = s == 'Yes'
    lte_list = ['color: #cc3300' if v else '' for v in is_lte]
    lte_list.append('')
    return lte_list[1:]

data_tariff_name_list = [f'DATA_{sponsor.name}' for sponsor in sponsors]

display(df_operator_compare.head(15).round(5).style.apply(highlight_max, subset=data_tariff_name_list, axis=1)\
        .apply(highlight_lte, axis=1).hide_index())

df_operator_compare.round(5).style.apply(highlight_max, subset=data_tariff_name_list, axis=1)\
        .apply(highlight_lte, axis=1).to_excel(join(downloads, file_operator_min_tariffs_lte), 'Sheet1', index=False)
# Out:
# <style  type="text/css" >
#     #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow0_col5 {
#             background-color:  #e6ffe6;
#             : ;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow0_col6 {
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow1_col5 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow1_col6 {
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow2_col2 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow2_col3 {
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow2_col5 {
#             : ;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow3_col5 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow3_col6 {
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow4_col2 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow4_col3 {
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow4_col5 {
#             : ;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow4_col6 {
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow5_col2 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow5_col5 {
#             : ;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow5_col6 {
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow6_col3 {
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow6_col5 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow6_col6 {
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow7_col2 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow7_col5 {
#             : ;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow7_col6 {
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow8_col2 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow8_col5 {
#             : ;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow8_col6 {
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow9_col2 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow9_col5 {
#             : ;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow9_col6 {
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow10_col2 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow10_col5 {
#             : ;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow10_col6 {
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow11_col3 {
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow11_col5 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow11_col6 {
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow12_col2 {
#             : ;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow12_col3 {
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow12_col5 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow12_col6 {
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow13_col2 {
#             : ;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow13_col3 {
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow13_col5 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow13_col6 {
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow14_col2 {
#             : ;
#             color:  #cc3300;
#         }    #T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow14_col5 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }</style><table id="T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9c" ><thead>    <tr>        <th class="col_heading level0 col0" >COUNTRY</th>        <th class="col_heading level0 col1" >NETWORK</th>        <th class="col_heading level0 col2" >DATA_S5</th>        <th class="col_heading level0 col3" >LTE_S5</th>        <th class="col_heading level0 col4" >CAMEL_S5</th>        <th class="col_heading level0 col5" >DATA_S8</th>        <th class="col_heading level0 col6" >LTE_S8</th>        <th class="col_heading level0 col7" >CAMEL_S8</th>        <th class="col_heading level0 col8" >DATA</th>        <th class="col_heading level0 col9" >SPONSOR</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow0_col0" class="data row0 col0" >Italy</td>
#                         <td id="T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow0_col1" class="data row0 col1" >Wind Telecomunicazioni S p A</td>
#                         <td id="T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow0_col2" class="data row0 col2" >nan</td>
#                         <td id="T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow0_col3" class="data row0 col3" >nan</td>
#                         <td id="T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow0_col4" class="data row0 col4" >nan</td>
#                         <td id="T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow0_col5" class="data row0 col5" >0.0048</td>
#                         <td id="T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow0_col6" class="data row0 col6" >No</td>
#                         <td id="T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow0_col7" class="data row0 col7" >Yes</td>
#                         <td id="T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow0_col8" class="data row0 col8" >1719.77</td>
#                         <td id="T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow0_col9" class="data row0 col9" >S1</td>
#             </tr>
#             <tr>
#                                 <td id="T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow1_col0" class="data row1 col0" >South Korea</td>
#                         <td id="T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow1_col1" class="data row1 col1" >KT Corporation</td>
#                         <td id="T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow1_col2" class="data row1 col2" >nan</td>
#                         <td id="T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow1_col3" class="data row1 col3" >nan</td>
#                         <td id="T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow1_col4" class="data row1 col4" >nan</td>
#                         <td id="T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow1_col5" class="data row1 col5" >0.0324</td>
#                         <td id="T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow1_col6" class="data row1 col6" >Yes</td>
#                         <td id="T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow1_col7" class="data row1 col7" >Yes</td>
#                         <td id="T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow1_col8" class="data row1 col8" >1149.36</td>
#                         <td id="T_dcdf08c6_270f_11ea_87a5_9cb6d0ea0f9crow1_col9" class="data row1 col9" >S1</td>
#             </tr>
#             <tr>

# %%
df_by_this = pd.read_csv(join(downloads,'CountryMinTariffLte_CombinedCreatedByThis.csv'), usecols=['COUNTRY','SPONSOR COMBINED 2020'])
df_by_this.head()
# Out:
#        COUNTRY SPONSOR COMBINED 2020
# 0  Afghanistan                    S8
# 1      Albania                    S1
# 2      Algeria                    S8
# 3      Andorra                    S1
# 4     Anguilla                    S1

# %%
# Подготовка DF для сравнения тарифов по странам с учетом LTE

df = DataFrame({'COUNTRY':[]})
for sponsor in sponsors:
    df_temp = sponsor.df_tariff.loc[:, ['COUNTRY', 'DATA', 'LTE']]
    df_temp = df_temp.loc[df_temp.groupby('COUNTRY')['DATA'].idxmin()]\
    .rename({'DATA':f'DATA_{sponsor.name}', 'LTE':f'LTE_{sponsor.name}'}, axis=1)
    df = pd.merge(df, df_temp.drop_duplicates(), how='outer', on='COUNTRY')

df = pd.merge(df, df_bss_processed.groupby('COUNTRY', as_index=False)['DATA'].sum(), how='left', on='COUNTRY')

df = pd.merge(df, df_al.groupby('COUNTRY', as_index=False)['SPONSOR'].first(), how='outer', on='COUNTRY')

df_country_compare = df.sort_values(by='DATA', ascending=False)
df_country_compare = pd.merge(df_country_compare, df_by_this, how='left', on='COUNTRY')

df_country_compare = df_country_compare.loc[df_country_compare.COUNTRY.isin(['Uruguay',
 'Mexico',
 'Chile',
 'Nicaragua',
 'Puerto Rico',
 'Guatemala',
 'Dominican Republic',
 'Paraguay',
 'Brazil',
 'Ecuador',
 'Macao China',
 'Peru',
 'Lesotho',
 'Honduras',
 'Argentina',
 'Indonesia',
 'Albania'])]

def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.min()
    return ['background-color: #e6ffe6' if v else '' for v in is_max]

def highlight_lte(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_lte = s == 'Yes'
    lte_list = ['color: #cc3300' if v else '' for v in is_lte]
    lte_list.append('')
    return lte_list[1:]

data_tariff_name_list = [f'DATA_{sponsor.name}' for sponsor in sponsors]

display(df_country_compare.head(15).round(5).style.apply(highlight_max, subset=data_tariff_name_list, axis=1)\
        .apply(highlight_lte, axis=1).hide_index())

df_country_compare.round(5).style.apply(highlight_max, subset=data_tariff_name_list, axis=1)\
        .apply(highlight_lte, axis=1).to_excel(join(downloads, file_country_min_tariffs_lte), 'Sheet1', index=False)
# Out:
# <style  type="text/css" >
#     #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow0_col1 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow0_col3 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow0_col7 {
#             background-color:  #e6ffe6;
#             : ;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow0_col9 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow1_col1 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow1_col3 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow1_col7 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow1_col9 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow2_col7 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow2_col9 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow3_col3 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow3_col7 {
#             background-color:  #e6ffe6;
#             : ;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow3_col9 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow4_col7 {
#             background-color:  #e6ffe6;
#             : ;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow4_col9 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow5_col1 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow5_col7 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow5_col9 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow6_col1 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow6_col3 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow7_col1 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow7_col5 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow7_col7 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow8_col1 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow8_col7 {
#             background-color:  #e6ffe6;
#             : ;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow8_col9 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow9_col1 {
#             background-color:  #e6ffe6;
#             : ;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow9_col9 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow10_col1 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow10_col5 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow10_col7 {
#             background-color:  #e6ffe6;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow10_col9 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow11_col1 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow11_col7 {
#             background-color:  #e6ffe6;
#             : ;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow12_col1 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow12_col7 {
#             background-color:  #e6ffe6;
#             : ;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow12_col9 {
#             : ;
#             color:  #cc3300;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow13_col7 {
#             background-color:  #e6ffe6;
#             : ;
#         }    #T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow14_col1 {
#             background-color:  #e6ffe6;
#             : ;
#         }</style><table id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9c" ><thead>    <tr>        <th class="col_heading level0 col0" >COUNTRY</th>        <th class="col_heading level0 col1" >DATA_S1</th>        <th class="col_heading level0 col2" >LTE_S1</th>        <th class="col_heading level0 col3" >DATA_S2</th>        <th class="col_heading level0 col4" >LTE_S2</th>        <th class="col_heading level0 col5" >DATA_S4</th>        <th class="col_heading level0 col6" >LTE_S4</th>        <th class="col_heading level0 col7" >DATA_S5</th>        <th class="col_heading level0 col8" >LTE_S5</th>        <th class="col_heading level0 col9" >DATA_S8</th>        <th class="col_heading level0 col10" >LTE_S8</th>        <th class="col_heading level0 col11" >DATA</th>        <th class="col_heading level0 col12" >SPONSOR</th>        <th class="col_heading level0 col13" >SPONSOR COMBINED 2020</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow0_col0" class="data row0 col0" >Mexico</td>
#                         <td id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow0_col1" class="data row0 col1" >0.014</td>
#                         <td id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow0_col2" class="data row0 col2" >Yes</td>
#                         <td id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow0_col3" class="data row0 col3" >0.046</td>
#                         <td id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow0_col4" class="data row0 col4" >Yes</td>
#                         <td id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow0_col5" class="data row0 col5" >nan</td>
#                         <td id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow0_col6" class="data row0 col6" >nan</td>
#                         <td id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow0_col7" class="data row0 col7" >0.0092</td>
#                         <td id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow0_col8" class="data row0 col8" >No</td>
#                         <td id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow0_col9" class="data row0 col9" >0.054</td>
#                         <td id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow0_col10" class="data row0 col10" >Yes</td>
#                         <td id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow0_col11" class="data row0 col11" >169.86</td>
#                         <td id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow0_col12" class="data row0 col12" >S1</td>
#                         <td id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow0_col13" class="data row0 col13" >S1</td>
#             </tr>
#             <tr>
#                                 <td id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow1_col0" class="data row1 col0" >Brazil</td>
#                         <td id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow1_col1" class="data row1 col1" >0.014</td>
#                         <td id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow1_col2" class="data row1 col2" >Yes</td>
#                         <td id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow1_col3" class="data row1 col3" >0.046</td>
#                         <td id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow1_col4" class="data row1 col4" >Yes</td>
#                         <td id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow1_col5" class="data row1 col5" >nan</td>
#                         <td id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f9crow1_col6" class="data row1 col6" >nan</td>
#                         <td id="T_3271d65c_27f3_11ea_a1af_9cb6d0ea0f
