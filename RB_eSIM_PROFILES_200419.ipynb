# %% [markdown]
# ### eSIM profiles
# - Готовится файл с eSIM для выдачи Касмтомерам

# %%
import pandas as pd
from pandas import Series, DataFrame
import datetime as dt
from os.path import join

# %%
downloads = r'c:\Users\balob\Documents\GITLAB\RB_BD\DATA\eSimProfiles\data'

if_keys = 'esim_rb_5k_18102019.out'

df_qr = pd.read_csv(join(downloads, 'RB_ICCID_QRCode_URL.csv'))
quantity = len(df_qr)

df_qr['ICCID_CD'] = df_qr.ICCID.str.slice(1,20)
df_qr.sort_values(by='ICCID_CD', inplace=True)
df_qr.reset_index(inplace=True, drop=True)

display(df_qr.head(3))
# Out:
#                    ICCID                                  QR_Code  \
# 0  '89972191210000870004   LPA:1$rsp.truphone.com$4K-51Q6Z-LEOFIF
# 1  '89972191210000870012  LPA:1$rsp.truphone.com$4K-51Q76-1OTW1RH
# 2  '89972191210000870020   LPA:1$rsp.truphone.com$4K-51Q7D-89EUBX
#
#               ICCID_CD
# 0  8997219121000087000
# 1  8997219121000087001
# 2  8997219121000087002

# %%
# Из базы данных OCS выгружаем IMSI
#----------------------------------

import pandas as pd
import pyodbc 
#Connect to OCSDBREP1 (BSS)
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER=172.18.11.82;DATABASE=10028;UID=BSS;PWD=iKQVm40AZAmyRaw72LeY')

sql_srt=\
'''
SELECT DISTINCT
r.RESELLER_NAME
,a.ACCOUNT_NAME
,ss.STATUS AS SUB_STATUS
,si.IMSI
,si.ICCID AS ICCID_CD
FROM RESELLERS r
INNER JOIN ACCOUNTS a
ON r.RESELLER_ID = a.RESELLER_ID
INNER JOIN SUBSCRIBERS sr
ON sr.ACCOUNT_ID = a.ACCOUNT_ID
INNER JOIN SUBSCRIBER_STATUS ss
ON ss.SUBSCRIBER_ID = sr.SUBSCRIBER_ID
INNER JOIN SUBSCRIBER_IMSIS si
ON ss.SUBSCRIBER_ID = si.SUBSCRIBER_ID
WHERE
r.deleted is NULL
AND ss.END_DATE IS NULL
AND ss.status IN ('Active', 'Disconnected')
AND
(si.IMSI BETWEEN '260060145010000' AND '260060145014999')
'''

df_ocs_imsi = pd.read_sql_query(sql_srt, cnxn, coerce_float=False)
df_ocs_imsi['IMSI'] = df_ocs_imsi['IMSI'].astype('int64')
cnxn.close()
df_ocs_imsi.head(3)
# Out:
#                              RESELLER_NAME ACCOUNT_NAME SUB_STATUS  \
# 0  Flexiroam Limited -- TESTING at 2018-07    Test eSIM     Active
# 1  Flexiroam Limited -- TESTING at 2018-07    Test eSIM     Active
# 2  Flexiroam Limited -- TESTING at 2018-07    Test eSIM     Active
#
#               IMSI             ICCID_CD
# 0  260060145014003  8997219121000091003
# 1  260060145014004  8997219121000091004
# 2  260060145014005  8997219121000091005

# %%
cols = ['ICCID','QR_Code','RESELLER_NAME','ACCOUNT_NAME', 'IMSI', 'SUB_STATUS']
df_batch = pd.merge(df_qr, df_ocs_imsi, on='ICCID_CD', how='left', suffixes=['_S2', '_S1'])

df_batch = df_batch[cols]
df_batch.head()
# Out:
#                    ICCID                                  QR_Code  \
# 0  '89972191210000870004   LPA:1$rsp.truphone.com$4K-51Q6Z-LEOFIF
# 1  '89972191210000870012  LPA:1$rsp.truphone.com$4K-51Q76-1OTW1RH
# 2  '89972191210000870020   LPA:1$rsp.truphone.com$4K-51Q7D-89EUBX
# 3  '89972191210000870038   LPA:1$rsp.truphone.com$4K-51Q9W-DK2E9Q
# 4  '89972191210000870046  LPA:1$rsp.truphone.com$4K-51Q7K-10DA1Y5
#
#     RESELLER_NAME ACCOUNT_NAME             IMSI SUB_STATUS
# 0  WMB Limited RT    WMB eSIMs  260060145010000     Active
# 1  WMB Limited RT    WMB eSIMs  260060145010001     Active
# 2  WMB Limited RT    WMB eSIMs  260060145010002     Active
# 3  WMB Limited RT    WMB eSIMs  260060145010003     Active
# 4  WMB Limited RT    WMB eSIMs  260060145010004     Active

# %%
list_agg = [('IMSI_MIN','min'),('IMSI_MAX','max'),('NUM','count')]
list_col = ['RESELLER_NAME', 'ACCOUNT_NAME', 'SUB_STATUS', df_batch.IMSI.astype('str').str.slice(0,12)]
df_batch_group = df_batch.groupby(list_col)['IMSI'].agg(list_agg).reset_index().sort_values(by='IMSI')
df_batch_group.sort_values('IMSI_MIN')
# Out:
#                               RESELLER_NAME                ACCOUNT_NAME  \
# 18                           WMB Limited RT                   WMB eSIMs
# 11                            STI - Telinta        ESIM_SW_Main_Account
# 10                            STI - Telinta                 ESIM_KALLER
# 9                             STI - Telinta     ESIM_GlobaleSIM_Website
# 7                             STI - Telinta                 ESIM_Adonis
# 8                             STI - Telinta                    ESIM_GVC
# 14                                   Simtex           Simtex eSIMs - IO
# 12                                   Simtex                  Arena Club
# 13                                   Simtex                   Auto Test
# 15                      Tottolli-Tech-Mobil              Test Sim cards
# 6                       Roamability Test RT  Roamability Test Sim-cards
# 0   Flexiroam Limited -- TESTING at 2018-07                   Test eSIM
# 1   Flexiroam Limited -- TESTING at 2018-07                   Test eSIM
# 17                                   Vision         Vision Test Account
# 16                      Tottolli-Tech-Mobil              Test Sim cards
# 3                                  Mobilise         MobiliseTestAccount
# 2                                  Freecell                        eSIM
# 5                Roamability Resellers Test              Mobiliseglobal
# 4                     Roamability Invertory  Roamability eSIM Inventory
#
#       SUB_STATUS          IMSI         IMSI_MIN         IMSI_MAX   NUM
# 18        Active  260060145010  260060145010000  260060145010999  1000
# 11        Active  260060145011  260060145011000  260060145011839   839
# 10        Active  260060145011  260060145011834  260060145011834     1
# 9         Active  260060145011  260060145011840  260060145011899    60
# 7         Active  260060145011  260060145011900  260060145011949    50
# 8         Active  260060145011  260060145011950  260060145011999    50
# 14        Active  260060145012  260060145012000  260060145012998   993
# 12        Active  260060145012  260060145012980  260060145012985     6
# 13        Active  260060145012  260060145012999  260060145012999     1
# 15        Active  260060145013  260060145013000  260060145013999  1000
# 6         Active  260060145014  260060145014000  260060145014002     3
# 0         Active  260060145014  260060145014003  260060145014006     4
# 1   Disconnected  260060145014  260060145014007  260060145014007     1
# 17        Active  260060145014  260060145014008  260060145014008     1
# 16        Active  260060145014  260060145014009  260060145014128   120
# 3         Active  260060145014  260060145014129  260060145014131     3
# 2         Active  260060145014  260060145014132  260060145014134     3
# 5         Active  260060145014  260060145014135  260060145014138     4
# 4         Active  260060145014  260060145014139  260060145014999   861

# %%
# Prepare the output file

qustomer = 'Tottoli'
imsi_start = 260060145014139
given_quantity = 5

current_date = dt.datetime.now().strftime('%y%m%d')

of_name = f'RB_eSIM_{qustomer}_{current_date}_{given_quantity}.csv'
df_customer = df_batch.loc[df_batch.IMSI.isin(range(imsi_start, imsi_start + given_quantity)),
       ['ICCID','QR_Code','IMSI']]

df_customer.QR_Code.replace(to_replace={r'\.*rsp.truphone.com\.*':'smdp.io'}, regex=True, inplace=True)

df_customer.to_csv(join(downloads, of_name), index=False)
df_customer.head()
# Out:
#                       ICCID                         QR_Code             IMSI
# 4139  '89972191210000911394   LPA:1$smdp.io$4K-52JRK-LPOAPP  260060145014139
# 4140  '89972191210000911402   LPA:1$smdp.io$4K-52JRR-I4CHB1  260060145014140
# 4141  '89972191210000911410  LPA:1$smdp.io$4K-52JRY-1L1Q1XR  260060145014141
# 4142  '89972191210000911428   LPA:1$smdp.io$4K-52JS5-AKTND0  260060145014142
# 4143  '89972191210000911436  LPA:1$smdp.io$4K-52JSC-1EFOZWF  260060145014143

# %% [markdown]
# ### Developments

# %%
df_batch.loc[df_batch.IMSI == 260060145014062]
# Out:
#                       ICCID                                 QR_Code  \
# 4062  '89972191210000910628  LPA:1$rsp.truphone.com$4K-52J8P-L7R1J2
#
#             RESELLER_NAME    ACCOUNT_NAME             IMSI SUB_STATUS
# 4062  Tottolli-Tech-Mobil  Test Sim cards  260060145014062     Active
