# %% [markdown]
# # С помощью данной методики можно найти свободные IMSI диапазоны, а также создать файл с ключами для отправки кастомеру

# %%
# Загрузить данные из файлов
# Задать имена аккаунтов и файлов
#----------------------------------

import pandas as pd
from pandas import DataFrame
from os.path import join, normpath
import datetime as dt
from collections import namedtuple

### Set the variables here ###

reseller_name = 'Tottolli-Tech-Mobil'
customer_name = 'Tech' # to use as a file name

account_s1 = 'Tottolli S1 Soft' # Account name with S1
account_s2 = '' # Account name with S2
account_s4 = '' # Account name with S4
account_s5 = '' # Account name with S5
account_s6 = '' # Account name with S6
account_s8 = '' # Account name with S8

##############################

sponsor_object = namedtuple('SponsorRange', 'sponsor test_range prod_range account_name')

s1_sponsor = sponsor_object('S1', '425019613998', '42501', account_s1)
s2_sponsor = sponsor_object('S2', '260060149991', '26006', account_s2)
s4_sponsor = sponsor_object('S4', '454030227305', '45403', account_s4)
s5_sponsor = sponsor_object('S5', '515030191000', '51503', account_s5)
s6_sponsor = sponsor_object('S6', '260036610100', '26003', account_s6)
s8_sponsor = sponsor_object('S8', '234500026400', '23450', account_s8)

downloads = r'c:\Users\Andrew\Documents\GITLAB\RB_BD\DATA\SoftProfiles\Data'
result_file = 'result_file.csv'
files = ['rb_42501_25_06_20181.txt',
         'rb_42501_2_09_20181.txt',
         'rb_26006_25_06_20181.txt',
         'rb_26006_2_09_20181.txt',
         'rb_26006_30_04_2019.txt',
         'rb_42501_30_04_2019.txt',
         'rb_45403_09_07_2019.txt',
         '454030227306000_454030227308999.out',
         '454030227310000_454030227310999.out',
         '515030191000000_515030191099999.out',
         'rb_soft_191103_s1.txt',
         'rb_soft_191103_s2.txt',
         'rb_soft_191103_s4.txt',
         'rb_soft_191107_s6.txt',
         'rb_soft_191107_s8.txt',
         'rb_soft_191207_s1.txt',
         'rb_soft_191207_s2.txt',
         'rb_soft_200317_s4.txt',
         'rb_soft_200317_s8.txt',]

sponsors = [s1_sponsor, s2_sponsor, s4_sponsor, s5_sponsor, s6_sponsor, s8_sponsor]

current_date = dt.datetime.now().strftime('%y%m%d')

df_imsi = DataFrame(columns = ['IMSI', 'KI', 'OPC'])

for file in files:
    df_imsi = df_imsi.append(pd.read_csv(join(downloads, file), sep=' ', engine='python'))

df_imsi.IMSI = df_imsi.IMSI.astype('int64')
df_imsi.sort_values(by = 'IMSI', inplace = True)

df_imsi.head(3)
# Out:
#               IMSI                                KI  \
# 0  234500026400000  693E4A067EEB7F66AD9FBD5D0AA3D1E6
# 1  234500026400001  0C12B4359E0AF6FA8D25E39C0662C3D5
# 2  234500026400002  EC3655E2752449C2E8B1F96F79F9A2FD
#
#                                 OPC
# 0  79EC10C3C95CED20C758681507904E6D
# 1  02DECFCAE2F9A6D1AED425ED810B2CA6
# 2  79798D3604C1EDF288F237963111E7FB

# %%
# Из базы данных OCS выгружаем IMSI
#----------------------------------

import pandas as pd
import pyodbc 
#Connect to OCSDBREP1 (BSS)
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER=172.18.11.82;DATABASE=10028;UID=BSS;PWD=iKQVm40AZAmyRaw72LeY')

sql_srt=\
'''
SELECT DISTINCT
r.RESELLER_NAME
,a.ACCOUNT_NAME
,ss.STATUS AS SUB_STATUS
,si.IMSI
FROM RESELLERS r
INNER JOIN ACCOUNTS a
ON r.RESELLER_ID = a.RESELLER_ID
INNER JOIN SUBSCRIBERS sr
ON sr.ACCOUNT_ID = a.ACCOUNT_ID
INNER JOIN SUBSCRIBER_STATUS ss
ON ss.SUBSCRIBER_ID = sr.SUBSCRIBER_ID
INNER JOIN SUBSCRIBER_IMSIS si
ON ss.SUBSCRIBER_ID = si.SUBSCRIBER_ID
WHERE
r.deleted is NULL
AND ss.END_DATE IS NULL
AND ss.status = 'Active'
AND
(si.IMSI BETWEEN '260060140890000' AND '260060140899999'
OR si.IMSI BETWEEN '260060149991100' AND '260060149999999'
OR si.IMSI BETWEEN '425019613998060' AND '425019613999999'
OR si.IMSI BETWEEN '425019629920000' AND '425019629939999'
OR si.IMSI BETWEEN '425019613790000' AND '425019613799999'
OR si.IMSI BETWEEN '425019613788000' AND '425019613789999'
OR si.IMSI BETWEEN '260060149982000' AND '260060149989999'
OR si.IMSI BETWEEN '454030227305000' AND '454030227305999'
OR si.IMSI BETWEEN '454030227306000' AND '454030227308999'
OR si.IMSI BETWEEN '454030227310000' AND '454030227310999'
OR si.IMSI BETWEEN '515030191000000' AND '515030191009999'
OR si.IMSI BETWEEN '425019613960000' AND '425019613989999'
OR si.IMSI BETWEEN '260060149940000' AND '260060149969999'
OR si.IMSI BETWEEN '454030227311000' AND '454030227319999'
OR si.IMSI BETWEEN '260036610100000' AND '260036610100999'
OR si.IMSI BETWEEN '234500026400000' AND '234500026400999'
OR si.IMSI BETWEEN '425019613930000' AND '425019613959999'
OR si.IMSI BETWEEN '260060149910000' AND '260060149939999'
OR si.IMSI BETWEEN '454030227615000' AND '454030227619999'
OR si.IMSI BETWEEN '234500026425000' AND '234500026434999')
'''

# OR si.IMSI BETWEEN '515030191000000' AND '515030191099999' # Full range of Smart

df_ocs_imsi = pd.read_sql_query(sql_srt, cnxn, coerce_float=False)
df_ocs_imsi['IMSI'] = df_ocs_imsi['IMSI'].astype('int64')
cnxn.close()
df_ocs_imsi.head(3)
# Out:
#   RESELLER_NAME             ACCOUNT_NAME SUB_STATUS             IMSI
# 0           1OT           Test SIM cards     Active  425019613998119
# 1   Clementvale  Clementvale S1 profiles     Active  425019613791002
# 2   Clementvale  Clementvale S1 profiles     Active  425019613791005

# %%
# Объединяем IMSI с ключами и данные OCS
#----------------------------------

df_ocs_imsi_ki = pd.merge(df_imsi, df_ocs_imsi, how='left', on='IMSI')
list_agg = [('IMSI_MIN','min'),('IMSI_MAX','max'),('NUM','count')]
list_col = ['RESELLER_NAME', 'ACCOUNT_NAME', 'SUB_STATUS', df_ocs_imsi_ki.IMSI.astype('str').str.slice(0,12)]
df_ocs_imsi_ki_group = df_ocs_imsi_ki.groupby(list_col)['IMSI'].agg(list_agg).reset_index().sort_values(by='IMSI')

df_ocs_imsi_ki_group.head(3)
# Out:
#                   RESELLER_NAME                ACCOUNT_NAME SUB_STATUS  \
# 299         Tottolli-Tech-Mobil            Tottolli S8 Soft     Active
# 241  Roamability Resellers Test                Showmac Soft     Active
# 212       Roamability Invertory  S8 Soft Profiles inventory     Active
#
#              IMSI         IMSI_MIN         IMSI_MAX  NUM
# 299  234500026400  234500026400002  234500026400021   20
# 241  234500026400  234500026400042  234500026400051   10
# 212  234500026400  234500026400052  234500026400999  948

# %%
# For test accounts to use the following ranges:
# S1: 425019613998*
# S2: 260060149991*
# S4: 4540302273050*
# S5: 515030191000*
# Выбрать свободные из "Roamability Invertory"

for sponsor in sponsors:
    print(f'{sponsor.sponsor} test IMSIs in OCS by Reseller:')
    display(df_ocs_imsi_ki_group[df_ocs_imsi_ki_group['IMSI'] == sponsor.test_range].sort_values('IMSI_MIN'))
# Out:
# S1 test IMSIs in OCS by Reseller:
#                                RESELLER_NAME  \
# 26   Flexiroam Limited -- TESTING at 2018-07
# 126                              MCN Telecom
# 261                      Tottolli-Tech-Mobil
# 13                   Dialoq - Genesisclub RT
# 114                              Joy_telecom
# 301                             Watchdata SG
# 159                                RedTea RT
# 231               Roamability Resellers Test
# 1                                        1OT
# 7                                       DENT
# 6                                       DENT
# 20                                   Drimsim
# 138                              MCN Telecom
# 236               Roamability Resellers Test
# 272                      Tottolli-Tech-Mobil
# 243               Roamability Resellers Test
# 209                    Roamability Invertory
# 64                                  Freecell
# 233               Roamability Resellers Test
# 257                                    Taggs
# 239               Roamability Resellers Test
# 16                   Dialoq - Genesisclub RT
# 246               Roamability Resellers Test
# 118                         Justworks Mobile
# 256                                 Simlocal
# 259                                   Taisys
#
#                           ACCOUNT_NAME SUB_STATUS          IMSI  \
# 26         Flexiroam Test Soft simcard     Active  425019613998
# 126               MCN Telecom Soft SIM     Active  425019613998
# 261                     Test Sim cards     Active  425019613998
# 13       Genesisclub Partner Soft test     Active  425019613998
# 114      Joy telecom Partner Soft test     Active  425019613998
# 301       Watchdata  Partner Soft test     Active  425019613998
# 159  RedTea TEST Soft-simcards account     Active  425019613998
# 231                Clementvale S1 soft     Active  425019613998
# 1                       Test SIM cards     Active  425019613998
# 7                           S1Profiles     Active  425019613998
# 6                    MultiImsiProfiles     Active  425019613998
# 20           Drimsim S1 Soft test IMSI     Active  425019613998
# 138            MCN Telecom Soft SIM S1     Active  425019613998
# 236                         Myrepublic     Active  425019613998
# 272                   Tottolli S1 Soft     Active  425019613998
# 243                       Showmac Soft     Active  425019613998
# 209    Partner Soft simcards inventory     Active  425019613998
# 64                    Freecell S1 Soft     Active  425019613998
# 233                        JCI S1 Soft     Active  425019613998
# 257                           Taggs S1     Active  425019613998
# 239                        Roamwifi S1     Active  425019613998
# 16                    Truphone S1 Soft     Active  425019613998
# 246                        VTB S1 soft     Active  425019613998
# 118         Justworks S1 test soft SIM     Active  425019613998
# 256                     Test SIM cards     Active  425019613998
# 259                     Test Sim cards     Active  425019613998
#
#             IMSI_MIN         IMSI_MAX  NUM
# 26   425019613998060  425019613998064    5
# 126  425019613998065  425019613998067    3
# 261  425019613998071  425019613998081    4
# 13   425019613998072  425019613998937   18
# 114  425019613998088  425019613998929    5
# 301  425019613998090  425019613998090    1
# 159  425019613998093  425019613998491   22
# 231  425019613998113  425019613998990    6
# 1    425019613998118  425019613998119    2
# 7    425019613998120  425019613998142   12
# 6    425019613998123  425019613998132   10
# 20   425019613998153  425019613998984  326
# 138  425019613998483  425019613998949   10
# 236  425019613998488  425019613998489    2
# 272  425019613998501  425019613998520   20
# 243  425019613998521  425019613998530   10
# 209  425019613998531  425019613998900  370
# 64   425019613998901  425019613998913   13
# 233  425019613998930  425019613998931    2
# 257  425019613998938  425019613998940    3
# 239  425019613998941  425019613998942    2
# 16   425019613998960  425019613998989   25
# 246  425019613998991  425019613998994    4
# 118  425019613998995  425019613998995    1
# 256  425019613998996  425019613998996    1
# 259  425019613998997  425019613998999    3
# S2 test IMSIs in OCS by Reseller:
#                                RESELLER_NAME                 ACCOUNT_NAME  \
# 25   Flexiroam Limited -- TESTING at 2018-07  Flexiroam Test Soft simcard
# 125                              MCN Telecom         MCN Telecom Soft SIM
# 12                   Dialoq - Genesisclub RT     Genesisclub P4 Soft test
# 302                             Watchdata SG       Watchdata P4 Soft test
# 22                                   Drimsim    Drimsim S2 Soft test IMSI
# 0                                        1OT               Test SIM cards
# 8                                       DENT                   S2Profiles
# 5                                       DENT            MultiImsiProfiles
# 238               Roamability Resellers Test              PointDume Multi
# 145                              MCN Telecom      MCN Telecom Soft SIM S2
# 252                      Roamability Test RT         Sigos Test Sim cards
# 235               Roamability Resellers Test                   Myrepublic
# 289                      Tottolli-Tech-Mobil             Tottolli S2 Soft
# 242               Roamability Resellers Test                 Showmac Soft
# 185                    Roamability Invertory   P4 Soft simcards inventory
# 100                                 Freecell             Freecell S2 Soft
# 113                              Joy_telecom     Joy telecom P4 Soft test
# 234               Roamability Resellers Test                  JCI S2 Soft
# 240               Roamability Resellers Test                  Roamwifi S2
# 17                   Dialoq - Genesisclub RT             Truphone S2 Soft
# 232               Roamability Resellers Test          Clementvale S2 soft
# 119                         Justworks Mobile   Justworks S2 test soft SIM
# 255                                 Simlocal               Test SIM cards
# 258                                   Taisys               Test Sim cards
#
#     SUB_STATUS          IMSI         IMSI_MIN         IMSI_MAX  NUM
# 25      Active  260060149991  260060149991100  260060149991104    5
# 125     Active  260060149991  260060149991105  260060149991107    3
# 12      Active  260060149991  260060149991110  260060149991945   18
# 302     Active  260060149991  260060149991123  260060149991123    1
# 22      Active  260060149991  260060149991124  260060149991949   12
# 0       Active  260060149991  260060149991135  260060149991135    1
# 8       Active  260060149991  260060149991136  260060149991158   12
# 5       Active  260060149991  260060149991138  260060149991478   21
# 238     Active  260060149991  260060149991479  260060149991498   20
# 145     Active  260060149991  260060149991499  260060149991954   10
# 252     Active  260060149991  260060149991504  260060149991504    1
# 235     Active  260060149991  260060149991505  260060149991506    2
# 289     Active  260060149991  260060149991517  260060149991536   20
# 242     Active  260060149991  260060149991537  260060149991546   10
# 185     Active  260060149991  260060149991547  260060149991908  362
# 100     Active  260060149991  260060149991909  260060149991921   13
# 113     Active  260060149991  260060149991937  260060149991996    3
# 234     Active  260060149991  260060149991938  260060149991939    2
# 240     Active  260060149991  260060149991946  260060149991947    2
# 17      Active  260060149991  260060149991965  260060149991991   25
# 232     Active  260060149991  260060149991992  260060149991992    1
# 119     Active  260060149991  260060149991993  260060149991993    1
# 255     Active  260060149991  260060149991994  260060149991994    1
# 258     Active  260060149991  260060149991997  260060149991999    3
# S4 test IMSIs in OCS by Reseller:
#                   RESELLER_NAME                         ACCOUNT_NAME  \
# 2                           1OT                       Test SIM cards
# 23                      Drimsim            Drimsim S4 Soft test IMSI
# 253         Roamability Test RT                 Sigos Test Sim cards
# 237  Roamability Resellers Test                           Myrepublic
# 295         Tottolli-Tech-Mobil                     Tottolli S4 Soft
# 244  Roamability Resellers Test                         Showmac Soft
# 160       Roamability Invertory  Multi Byte Soft Profiles Inventory
# 11      Dialoq - Genesisclub RT                      Dailoq S2+S1+S4
#
#     SUB_STATUS          IMSI         IMSI_MIN         IMSI_MAX  NUM
# 2       Active  454030227305  454030227305015  454030227305016    2
# 23      Active  454030227305  454030227305117  454030227305141   25
# 253     Active  454030227305  454030227305142  454030227305142    1
# 237     Active  454030227305  454030227305143  454030227305144    2
# 295     Active  454030227305  454030227305145  454030227305164   20
# 244     Active  454030227305  454030227305165  454030227305174   10
# 160     Active  454030227305  454030227305175  454030227305349  175
# 11      Active  454030227305  454030227305350  454030227305499  150
# S5 test IMSIs in OCS by Reseller:
#                   RESELLER_NAME                   ACCOUNT_NAME SUB_STATUS  \
# 24                      Drimsim      Drimsim S5 Soft test IMSI     Active
# 117                 Joy_telecom            Joy telecom S5 Soft     Active
# 249         Roamability Test RT       RedTea S5 Test SIM cards     Active
# 254         Roamability Test RT           Sigos Test Sim cards     Active
# 146             Mondicon SIM RT               S5 soft profiles     Active
# 297         Tottolli-Tech-Mobil               Tottolli S5 Soft     Active
# 18      Dialoq - Genesisclub RT               Truphone S5 Soft     Active
# 245  Roamability Resellers Test                   Showmac Soft     Active
# 247         Roamability Test RT                         DID's      Active
# 222       Roamability Invertory  Smart Soft Profiles inventory     Active
#
#              IMSI         IMSI_MIN         IMSI_MAX  NUM
# 24   515030191000  515030191000000  515030191000024   25
# 117  515030191000  515030191000025  515030191000034   10
# 249  515030191000  515030191000035  515030191000035    1
# 254  515030191000  515030191000036  515030191000036    1
# 146  515030191000  515030191000037  515030191000056   20
# 297  515030191000  515030191000057  515030191000076   20
# 18   515030191000  515030191000077  515030191000096   20
# 245  515030191000  515030191000097  515030191000106   10
# 247  515030191000  515030191000107  515030191000206  100
# 222  515030191000  515030191000207  515030191000999  793
# S6 test IMSIs in OCS by Reseller:
#              RESELLER_NAME                ACCOUNT_NAME SUB_STATUS  \
# 251    Roamability Test RT        Sigos Test Sim cards     Active
# 248    Roamability Test RT       Orange Test Sim cards     Active
# 211  Roamability Invertory  S6 Soft Profiles inventory     Active
#
#              IMSI         IMSI_MIN         IMSI_MAX  NUM
# 251  260036610100  260036610100000  260036610100000    1
# 248  260036610100  260036610100001  260036610100002    2
# 211  260036610100  260036610100003  260036610100999  997
# S8 test IMSIs in OCS by Reseller:
#                   RESELLER_NAME                ACCOUNT_NAME SUB_STATUS  \
# 250         Roamability Test RT        Sigos Test Sim cards     Active
# 299         Tottolli-Tech-Mobil            Tottolli S8 Soft     Active
# 19      Dialoq - Genesisclub RT            Truphone S8 Soft     Active
# 241  Roamability Resellers Test                Showmac Soft     Active
# 212       Roamability Invertory  S8 Soft Profiles inventory     Active
#
#              IMSI         IMSI_MIN         IMSI_MAX  NUM
# 250  234500026400  234500026400000  234500026400000    1
# 299  234500026400  234500026400002  234500026400021   20
# 19   234500026400  234500026400022  234500026400041   20
# 241  234500026400  234500026400042  234500026400051   10
# 212  234500026400  234500026400052  234500026400999  948

# %%
# For commersial usage

for sponsor in sponsors:
    print(f'{sponsor.sponsor} prod IMSIs in OCS by Reseller:')
    display(df_ocs_imsi_ki_group[(df_ocs_imsi_ki_group.IMSI.str.startswith(sponsor.prod_range, na=False))
                                 & (df_ocs_imsi_ki_group.RESELLER_NAME == 'Roamability Invertory')
                                ].sort_values('IMSI_MIN'))
# Out:
# S1 prod IMSIs in OCS by Reseller:
#              RESELLER_NAME                     ACCOUNT_NAME SUB_STATUS  \
# 193  Roamability Invertory  Partner Soft simcards inventory     Active
# 194  Roamability Invertory  Partner Soft simcards inventory     Active
# 195  Roamability Invertory  Partner Soft simcards inventory     Active
# 196  Roamability Invertory  Partner Soft simcards inventory     Active
# 197  Roamability Invertory  Partner Soft simcards inventory     Active
# 198  Roamability Invertory  Partner Soft simcards inventory     Active
# 199  Roamability Invertory  Partner Soft simcards inventory     Active
# 200  Roamability Invertory  Partner Soft simcards inventory     Active
# 201  Roamability Invertory  Partner Soft simcards inventory     Active
# 202  Roamability Invertory  Partner Soft simcards inventory     Active
# 203  Roamability Invertory  Partner Soft simcards inventory     Active
# 204  Roamability Invertory  Partner Soft simcards inventory     Active
# 205  Roamability Invertory  Partner Soft simcards inventory     Active
# 206  Roamability Invertory  Partner Soft simcards inventory     Active
# 207  Roamability Invertory  Partner Soft simcards inventory     Active
# 208  Roamability Invertory  Partner Soft simcards inventory     Active
# 209  Roamability Invertory  Partner Soft simcards inventory     Active
# 210  Roamability Invertory  Partner Soft simcards inventory     Active
#
#              IMSI         IMSI_MIN         IMSI_MAX   NUM
# 193  425019613959  425019613959000  425019613959999  1000
# 194  425019613975  425019613975000  425019613975999  1000
# 195  425019613976  425019613976000  425019613976999  1000
# 196  425019613977  425019613977000  425019613977999  1000
# 197  425019613978  425019613978000  425019613978999  1000
# 198  425019613979  425019613979000  425019613979999  1000
# 199  425019613980  425019613980000  425019613980999  1000
# 200  425019613981  425019613981000  425019613981999  1000
# 201  425019613982  425019613982000  425019613982999  1000
# 202  425019613983  425019613983000  425019613983999  1000
# 203  425019613984  425019613984000  425019613984999  1000
# 204  425019613985  425019613985000  425019613985999  1000
# 205  425019613986  425019613986000  425019613986999  1000
# 206  425019613987  425019613987000  425019613987999  1000
# 207  425019613988  425019613988000  425019613988999  1000
# 208  425019613989  425019613989000  425019613989999  1000
# 209  425019613998  425019613998531  425019613998900   370
# 210  425019613999  425019613999750  425019613999997   248
# S2 prod IMSIs in OCS by Reseller:
#              RESELLER_NAME                ACCOUNT_NAME SUB_STATUS  \
# 162  Roamability Invertory  P4 Soft simcards inventory     Active
# 163  Roamability Invertory  P4 Soft simcards inventory     Active
# 164  Roamability Invertory  P4 Soft simcards inventory     Active
# 165  Roamability Invertory  P4 Soft simcards inventory     Active
# 166  Roamability Invertory  P4 Soft simcards inventory     Active
# 167  Roamability Invertory  P4 Soft simcards inventory     Active
# 168  Roamability Invertory  P4 Soft simcards inventory     Active
# 169  Roamability Invertory  P4 Soft simcards inventory     Active
# 170  Roamability Invertory  P4 Soft simcards inventory     Active
# 171  Roamability Invertory  P4 Soft simcards inventory     Active
# 172  Roamability Invertory  P4 Soft simcards inventory     Active
# 173  Roamability Invertory  P4 Soft simcards inventory     Active
# 174  Roamability Invertory  P4 Soft simcards inventory     Active
# 175  Roamability Invertory  P4 Soft simcards inventory     Active
# 176  Roamability Invertory  P4 Soft simcards inventory     Active
# 177  Roamability Invertory  P4 Soft simcards inventory     Active
# 178  Roamability Invertory  P4 Soft simcards inventory     Active
# 179  Roamability Invertory  P4 Soft simcards inventory     Active
# 180  Roamability Invertory  P4 Soft simcards inventory     Active
# 181  Roamability Invertory  P4 Soft simcards inventory     Active
# 182  Roamability Invertory  P4 Soft simcards inventory     Active
# 183  Roamability Invertory  P4 Soft simcards inventory     Active
# 184  Roamability Invertory  P4 Soft simcards inventory     Active
# 185  Roamability Invertory  P4 Soft simcards inventory     Active
# 186  Roamability Invertory  P4 Soft simcards inventory     Active
# 187  Roamability Invertory  P4 Soft simcards inventory     Active
#
#              IMSI         IMSI_MIN         IMSI_MAX   NUM
# 162  260060149939  260060149939000  260060149939999  1000
# 163  260060149956  260060149956500  260060149956999   500
# 164  260060149957  260060149957000  260060149957999  1000
# 165  260060149958  260060149958000  260060149958999  1000
# 166  260060149959  260060149959000  260060149959999  1000
# 167  260060149960  260060149960000  260060149960999  1000
# 168  260060149961  260060149961000  260060149961999  1000
# 169  260060149962  260060149962000  260060149962999  1000
# 170  260060149963  260060149963000  260060149963999  1000
# 171  260060149964  260060149964000  260060149964999  1000
# 172  260060149965  260060149965000  260060149965999  1000
# 173  260060149966  260060149966000  260060149966999  1000
# 174  260060149967  260060149967000  260060149967999  1000
# 175  260060149968  260060149968000  260060149968999  1000
# 176  260060149969  260060149969000  260060149969999  1000
# 177  260060149982  260060149982000  260060149982999  1000
# 178  260060149983  260060149983000  260060149983999  1000
# 179  260060149984  260060149984000  260060149984999  1000
# 180  260060149985  260060149985000  260060149985999  1000
# 181  260060149986  260060149986000  260060149986999  1000
# 182  260060149987  260060149987000  260060149987999  1000
# 183  260060149988  260060149988000  260060149988999  1000
# 184  260060149989  260060149989000  260060149989999  1000
# 185  260060149991  260060149991547  260060149991908   362
# 186  260060149992  260060149992000  260060149992999  1000
# 187  260060149999  260060149999750  260060149999992   243
# S4 prod IMSIs in OCS by Reseller:
#              RESELLER_NAME                         ACCOUNT_NAME SUB_STATUS  \
# 160  Roamability Invertory  Multi Byte Soft Profiles Inventory      Active
# 161  Roamability Invertory  Multi Byte Soft Profiles Inventory      Active
# 188  Roamability Invertory           P4 Soft simcards inventory     Active
# 189  Roamability Invertory           P4 Soft simcards inventory     Active
# 190  Roamability Invertory           P4 Soft simcards inventory     Active
# 191  Roamability Invertory           P4 Soft simcards inventory     Active
# 192  Roamability Invertory           P4 Soft simcards inventory     Active
#
#              IMSI         IMSI_MIN         IMSI_MAX   NUM
# 160  454030227305  454030227305175  454030227305349   175
# 161  454030227306  454030227306300  454030227306999   700
# 188  454030227615  454030227615000  454030227615999  1000
# 189  454030227616  454030227616000  454030227616999  1000
# 190  454030227617  454030227617000  454030227617999  1000
# 191  454030227618  454030227618000  454030227618999  1000
# 192  454030227619  454030227619000  454030227619999  1000
# S5 prod IMSIs in OCS by Reseller:
#              RESELLER_NAME                   ACCOUNT_NAME SUB_STATUS  \
# 222  Roamability Invertory  Smart Soft Profiles inventory     Active
# 223  Roamability Invertory  Smart Soft Profiles inventory     Active
# 224  Roamability Invertory  Smart Soft Profiles inventory     Active
# 225  Roamability Invertory  Smart Soft Profiles inventory     Active
# 226  Roamability Invertory  Smart Soft Profiles inventory     Active
# 227  Roamability Invertory  Smart Soft Profiles inventory     Active
# 228  Roamability Invertory  Smart Soft Profiles inventory     Active
# 229  Roamability Invertory  Smart Soft Profiles inventory     Active
# 230  Roamability Invertory  Smart Soft Profiles inventory     Active
#
#              IMSI         IMSI_MIN         IMSI_MAX   NUM
# 222  515030191000  515030191000207  515030191000999   793
# 223  515030191001  515030191001300  515030191001999   700
# 224  515030191003  515030191003000  515030191003999  1000
# 225  515030191004  515030191004000  515030191004999  1000
# 226  515030191005  515030191005000  515030191005999  1000
# 227  515030191006  515030191006000  515030191006999  1000
# 228  515030191007  515030191007000  515030191007999  1000
# 229  515030191008  515030191008000  515030191008999  1000
# 230  515030191009  515030191009000  515030191009999  1000
# S6 prod IMSIs in OCS by Reseller:
#              RESELLER_NAME                ACCOUNT_NAME SUB_STATUS  \
# 211  Roamability Invertory  S6 Soft Profiles inventory     Active
#
#              IMSI         IMSI_MIN         IMSI_MAX  NUM
# 211  260036610100  260036610100003  260036610100999  997
# S8 prod IMSIs in OCS by Reseller:
#              RESELLER_NAME                ACCOUNT_NAME SUB_STATUS  \
# 212  Roamability Invertory  S8 Soft Profiles inventory     Active
# 213  Roamability Invertory  S8 Soft Profiles inventory     Active
# 214  Roamability Invertory  S8 Soft Profiles inventory     Active
# 215  Roamability Invertory  S8 Soft Profiles inventory     Active
# 216  Roamability Invertory  S8 Soft Profiles inventory     Active
# 217  Roamability Invertory  S8 Soft Profiles inventory     Active
# 218  Roamability Invertory  S8 Soft Profiles inventory     Active
# 219  Roamability Invertory  S8 Soft Profiles inventory     Active
# 220  Roamability Invertory  S8 Soft Profiles inventory     Active
# 221  Roamability Invertory  S8 Soft Profiles inventory     Active
#
#              IMSI         IMSI_MIN         IMSI_MAX   NUM
# 212  234500026400  234500026400052  234500026400999   948
# 213  234500026426  234500026426000  234500026426999  1000
# 214  234500026427  234500026427000  234500026427999  1000
# 215  234500026428  234500026428000  234500026428999  1000
# 216  234500026429  234500026429000  234500026429999  1000
# 217  234500026430  234500026430000  234500026430999  1000
# 218  234500026431  234500026431000  234500026431999  1000
# 219  234500026432  234500026432000  234500026432999  1000
# 220  234500026433  234500026433000  234500026433999  1000
# 221  234500026434  234500026434000  234500026434999  1000

# %%
# Записать выбранные диапазоны IMSI
# Проверить выбранные IMSI на принадлежность к "Roamability Invertory"

# После переноса IMSI в аккаунты Кастомеров проверить выбранные IMSI и диапазоны
# (предварительно перезагрузив данные из OCS)

imsi_range_object = namedtuple('ImsiRange', 'sponsor imsi_list')

def imsi_list(range_start, range_end):
    return [str(imsi) for imsi in range(range_start, range_end+1,1)]

### Set the IMSI ranges here ###

s1_imsi_range = imsi_range_object('S1', imsi_list(425019613975000, 425019613977999))
s2_imsi_range = imsi_range_object('S2', imsi_list(0, 0))
s4_imsi_range = imsi_range_object('S4', imsi_list(0, 0))
s5_imsi_range = imsi_range_object('S5', imsi_list(0, 0))
s6_imsi_range = imsi_range_object('S6', imsi_list(0, 0))
s8_imsi_range = imsi_range_object('S8', imsi_list(0, 0))

#################################

imsi_ranges = [s1_imsi_range, s2_imsi_range, s4_imsi_range, s5_imsi_range, s6_imsi_range, s8_imsi_range]

for imsi_range in imsi_ranges:
    if imsi_range.imsi_list:
        display(df_ocs_imsi[df_ocs_imsi.IMSI.astype('str').isin(imsi_range.imsi_list)].groupby(['RESELLER_NAME',
                                                                                'ACCOUNT_NAME','SUB_STATUS']).count())
# Out:
#                                                                   IMSI
# RESELLER_NAME         ACCOUNT_NAME                    SUB_STATUS
# Roamability Invertory Partner Soft simcards inventory Active      3000
# Empty DataFrame
# Columns: [IMSI]
# Index: []
# Empty DataFrame
# Columns: [IMSI]
# Index: []
# Empty DataFrame
# Columns: [IMSI]
# Index: []
# Empty DataFrame
# Columns: [IMSI]
# Index: []
# Empty DataFrame
# Columns: [IMSI]
# Index: []

# %%
# Выгружаем файлы с ключами для диапазонов IMSI
#----------------------------------

for sponsor, imsi_range in zip(sponsors, imsi_ranges):
    if sponsor.account_name and imsi_range.imsi_list:
        df_ocs_imsi_ki.loc[(df_ocs_imsi_ki.RESELLER_NAME == reseller_name)
                           & (df_ocs_imsi_ki.ACCOUNT_NAME == sponsor.account_name)
                           & (df_ocs_imsi_ki.IMSI.astype('str').isin(imsi_range.imsi_list)),
                           ['IMSI', 'KI', 'OPC']].\
        to_csv(join(downloads, f'{sponsor.sponsor}_{customer_name}_{current_date}.txt'), index=False)
        print(f'{sponsor.sponsor}_{customer_name}_{current_date}.txt')
# Out:
# S1_Tech_200501.txt

# %% [markdown]
# ### Далее шифруем и отправляем
# ----------------------------------
# 1. Упаковать оба файла в zip архив.
# 2. Выполнить экспорт открытого ключа Кастомера (дважды кликнуть по файлу ключа).
# 3. В папке с архивом по пр.кл. на zip архив и выбрать "Зашифровать"
# 4. Зашифровать своим ключем *_FOR_KEYS
# 5. Отправить кастомеру. Свой ключ отправлять не нужно.
